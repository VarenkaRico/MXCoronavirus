# %%
import os
from zipfile import ZipFile
import glob, os
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
import pandas as pd
import fnmatch
import datetime as dt
from statistics import median
from matplotlib.ticker import PercentFormatter
from matplotlib import font_manager as fm

# %%
zip_files=glob.glob('Bases/*.zip')
extracted_files=glob.glob('*.csv')
#zip_files
num_files=len(zip_files)
print(extracted_files)
# Out:
# ['200412COVID19MEXICO.csv', '200413COVID19MEXICO.csv', '200414COVID19MEXICO.csv', '200415COVID19MEXICO.csv', '200416COVID19MEXICO.csv', '200417COVID19MEXICO.csv', '200418COVID19MEXICO.csv', '200419COVID19MEXICO.csv', '200420COVID19MEXICO.csv', '200421COVID19MEXICO.csv', '200422COVID19MEXICO.csv', '200423COVID19MEXICO.csv', '200424COVID19MEXICO.csv', '200425COVID19MEXICO.csv', '200426COVID19MEXICO.csv', '200427COVID19MEXICO.csv', '200428COVID19MEXICO.csv', '200429COVID19MEXICO.csv', '200430COVID19MEXICO.csv', '200501COVID19MEXICO.csv', '200502COVID19MEXICO.csv', '200503COVID19MEXICO.csv', '200504COVID19MEXICO.csv', '200505COVID19MEXICO.csv', '200506COVID19MEXICO.csv', '200507COVID19MEXICO.csv', '200508COVID19MEXICO.csv', '200509COVID19MEXICO.csv', '200510COVID19MEXICO.csv', '200511COVID19MEXICO.csv', '200512COVID19MEXICO.csv', '200513COVID19MEXICO.csv', '200514COVID19MEXICO.csv', '200515COVID19MEXICO.csv', '200516COVID19MEXICO.csv', '200517COVID19MEXICO.csv', '200518COVID19MEXICO.csv', '200519COVID19MEXICO.csv', '200520COVID19MEXICO.csv', '200521COVID19MEXICO.csv', '200522COVID19MEXICO.csv', '200523COVID19MEXICO.csv', '200524COVID19MEXICO.csv', '200525COVID19MEXICO.csv', '200526COVID19MEXICO.csv', '200527COVID19MEXICO.csv', '200528COVID19MEXICO.csv', '200529COVID19MEXICO.csv', '200530COVID19MEXICO.csv', '200531COVID19MEXICO.csv', '200601COVID19MEXICO.csv', '200602COVID19MEXICO.csv', '200603COVID19MEXICO.csv', '200604COVID19MEXICO.csv', '200605COVID19MEXICO.csv', '200606COVID19MEXICO.csv', '200607COVID19MEXICO.csv', '200608COVID19MEXICO.csv', '200609COVID19MEXICO.csv', '200610COVID19MEXICO.csv', '200611COVID19MEXICO.csv', '200612COVID19MEXICO.csv', '200614COVID19MEXICO.csv', '200615COVID19MEXICO.csv', '200616COVID19MEXICO.csv', '200617COVID19MEXICO.csv', '200618COVID19MEXICO.csv', '200619COVID19MEXICO.csv', '200620COVID19MEXICO.csv', '200621COVID19MEXICO.csv', '200622COVID19MEXICO.csv']

# %% [markdown]
# DATOS DESCARGADOS DESDE https://www.gob.mx/salud/documentos/datos-abiertos-152127

# %% [markdown]
# # Obtener información

# %%
file_name=zip_files[0]
file_name=file_name.split("Bases\\")[1].split(".zip",1)[0]
file_name
# Out:
# 'datos_abiertos_covid19_01.05.2020'

# %% [markdown]
# ## Extracción de Archivos Zip

# %%
for f in range(num_files):
    #print(f)
    file=zip_files[f]
    with ZipFile (file,"r") as zip:
        
        ##GET FILE NAME
        file_name=zip.namelist()
        #print(file_name)
        
        ##SEARCH IF THE FILE WAS ALREADY EXTRACTED BEFORE
        if file_name[0] in extracted_files:
            next
            #print(str(file_name) + "already extracted")
        
        ##IF THE FILE WAS NOT EXTRACTED BEFORE, THEN EXTRACT AND NOTICE
        else:
            print("added" + str(file_name))
            zip.extractall()
            extracted_files=glob.glob('*.csv')
# Out:
# added['200613COVID19MEXICO.csv']

# %% [markdown]
# ## Carga de bases, catálogo y descriptores

# %%
# CATALOGOS
Catalogos=pd.ExcelFile("diccionario_datos_covid19/Catalogos_0412.xlsx")
Catalogos.sheet_names
# Out:
# ['Catálogo ORIGEN',
#  'Catálogo SECTOR',
#  'Catálogo SEXO',
#  'Catálogo TIPO_PACIENTE',
#  'Catálogo SI_NO',
#  'Catálogo NACIONALIDAD',
#  'Catálogo RESULTADO',
#  'Catálogo de ENTIDADES',
#  'Catálogo MUNICIPIOS']

# %%
pd.read_excel("diccionario_datos_covid19/Catalogos_0412.xlsx",sheet_name="Catálogo TIPO_PACIENTE").head()
# Out:
#    CLAVE      DESCRIPCIÓN
# 0      1      AMBULATORIO
# 1      2    HOSPITALIZADO
# 2     99  NO ESPECIFICADO

# %%
pd.read_excel("diccionario_datos_covid19/Catalogos_0412.xlsx",sheet_name="Catálogo RESULTADO").head()
# Out:
#   Unnamed: 0              Unnamed: 1
# 0      CLAVE             DESCRIPCIÓN
# 1          1     Positivo SARS-CoV-2
# 2          2  No positivo SARS-CoV-2
# 3          3     Resultado pendiente

# %%
pd.read_excel("diccionario_datos_covid19/Catalogos_0412.xlsx",sheet_name="Catálogo SI_NO").head()
# Out:
#    CLAVE      DESCRIPCIÓN
# 0      1              SI
# 1      2              NO
# 2     97        NO APLICA
# 3     98        SE IGNORA
# 4     99  NO ESPECIFICADO

# %%
#DESCRIPTORES
Descriptores=pd.read_excel("diccionario_datos_covid19/Descriptores_0419.xlsx")
Descriptores.head()
# Out:
#    Nº   NOMBRE DE VARIABLE                            DESCRIPCIÓN DE VARIABLE  \
# 0   1  FECHA_ACTUALIZACION  La base de datos se alimenta diariamente, esta...
# 1   2          ID_REGISTRO                      Número identificador del caso
# 2   3               ORIGEN  La vigilancia centinela se realiza a través de...
# 3   4               SECTOR  Identifica el tipo de institución del Sistema ...
# 4   5           ENTIDAD_UM  Identifica la entidad donde se ubica la unidad...
#
#                                     FORMATO O FUENTE
# 0                                         AAAA-MM-DD
# 1                                             TEXTO
# 2  CATÁLOGO: ORIGEN                              ...
# 3  CATÁLOGO: SECTOR                              ...
# 4                                CATALÓGO: ENTIDADES

# %%
pd.read_excel("diccionario_datos_covid19/Catalogos_0412.xlsx",sheet_name="Catálogo RESULTADO")
# Out:
#   Unnamed: 0              Unnamed: 1
# 0      CLAVE             DESCRIPCIÓN
# 1          1     Positivo SARS-CoV-2
# 2          2  No positivo SARS-CoV-2
# 3          3     Resultado pendiente

# %%
#Bases de casos
for f in range(len(extracted_files)):
    if f == 0:
        current_file_name=extracted_files[f]
        total_dbs=pd.read_csv(current_file_name)
        fecha_real="20"+current_file_name[0:2]+"-"+current_file_name[2:4]+"-"+current_file_name[4:6]
        
        #Sustituye la Fecha_Actualizacion con la Fecha en el nombre del archivo
        if total_dbs["FECHA_ACTUALIZACION"][0]!=fecha_real:
            total_dbs["FECHA_ACTUALIZACION"]=fecha_real
        
        os.remove(current_file_name)
    else:
        current_file_name=extracted_files[f]
        current_file=pd.read_csv(current_file_name,encoding='latin-1')
        
        fecha_real="20"+current_file_name[0:2]+"-"+current_file_name[2:4]+"-"+current_file_name[4:6]
        
        
        #Sustituye la Fecha_Actualizacion con la Fecha en el nombre del archivo
        if current_file["FECHA_ACTUALIZACION"][0]!=fecha_real:
            current_file["FECHA_ACTUALIZACION"]=fecha_real
            
        total_dbs=total_dbs.append(current_file)
        
        os.remove(current_file_name)
# Out:
# C:\Users\varicoj\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#Comprobación de bases cargads
reportes=total_dbs.FECHA_ACTUALIZACION.unique()
reportes
primer_reporte=reportes.min()
ultimo_reporte=reportes.max()

# %%
total_dbs.columns
# Out:
# Index(['FECHA_ACTUALIZACION', 'ID_REGISTRO', 'ORIGEN', 'SECTOR', 'ENTIDAD_UM',
#        'SEXO', 'ENTIDAD_NAC', 'ENTIDAD_RES', 'MUNICIPIO_RES', 'TIPO_PACIENTE',
#        'FECHA_INGRESO', 'FECHA_SINTOMAS', 'FECHA_DEF', 'INTUBADO', 'NEUMONIA',
#        'EDAD', 'NACIONALIDAD', 'EMBARAZO', 'HABLA_LENGUA_INDIG', 'DIABETES',
#        'EPOC', 'ASMA', 'INMUSUPR', 'HIPERTENSION', 'OTRA_COM',
#        'CARDIOVASCULAR', 'OBESIDAD', 'RENAL_CRONICA', 'TABAQUISMO',
#        'OTRO_CASO', 'RESULTADO', 'MIGRANTE', 'PAIS_NACIONALIDAD',
#        'PAIS_ORIGEN', 'UCI'],
#       dtype='object')

# %% [markdown]
# # LIMPIEZA DATA

# %% [markdown]
# ## Obtener información de Descriptores

# %%
#Elimina acentos en Descriptores[Formato o Fuente]
Descriptores["FORMATO O FUENTE"]=Descriptores["FORMATO O FUENTE"].str.replace("Á","A")
Descriptores["FORMATO O FUENTE"]=Descriptores["FORMATO O FUENTE"].str.replace("Ó","O")
Descriptores["NOMBRE DE VARIABLE"]=Descriptores["NOMBRE DE VARIABLE"].str.replace("OTRAS_COM","OTRA_COM")
Descriptores
# Out:
#     Nº   NOMBRE DE VARIABLE  \
# 0    1  FECHA_ACTUALIZACION
# 1    2          ID_REGISTRO
# 2    3               ORIGEN
# 3    4               SECTOR
# 4    5           ENTIDAD_UM
# 5    6                 SEXO
# 6    7          ENTIDAD_NAC
# 7    8          ENTIDAD_RES
# 8    9        MUNICIPIO_RES
# 9   10        TIPO_PACIENTE
# 10  11        FECHA_INGRESO
# 11  12       FECHA_SINTOMAS
# 12  13            FECHA_DEF
# 13  14             INTUBADO
# 14  15             NEUMONIA
# 15  16                 EDAD
# 16  17         NACIONALIDAD
# 17  18             EMBARAZO
# 18  19   HABLA_LENGUA_INDIG
# 19  20             DIABETES
# 20  21                 EPOC
# 21  22                 ASMA
# 22  23             INMUSUPR
# 23  24         HIPERTENSION
# 24  25             OTRA_COM
# 25  26       CARDIOVASCULAR
# 26  27             OBESIDAD
# 27  28        RENAL_CRONICA
# 28  29           TABAQUISMO
# 29  30            OTRO_CASO
# 30  31            RESULTADO
# 31  32             MIGRANTE
# 32  33    PAIS_NACIONALIDAD
# 33  34          PAIS_ORIGEN
# 34  35                  UCI
#
#                               DESCRIPCIÓN DE VARIABLE  \
# 0   La base de datos se alimenta diariamente, esta...
# 1                       Número identificador del caso
# 2   La vigilancia centinela se realiza a través de...
# 3   Identifica el tipo de institución del Sistema ...
# 4   Identifica la entidad donde se ubica la unidad...
# 5                    Identifica al sexo del paciente.
# 6   Identifica la entidad de nacimiento del paciente.
# 7   Identifica la entidad de residencia del paciente.
# 8   Identifica el municipio de residencia del paci...
# 9   Identifica el tipo de atención que recibió el ...
# 10  Identifica la fecha de ingreso del paciente a ...
# 11  Idenitifica la fecha en que inició la sintomat...
# 12   Identifica la fecha en que el paciente falleció.
# 13  Identifica si el paciente requirió de intubación.
# 14  Identifica si al paciente se le diagnosticó co...
# 15                   Identifica la edad del paciente.
# 16  Identifica si el paciente es mexicano o extran...
# 17         Identifica si la paciente está embarazada.
# 18   Identifica si el paciente habla lengua índigena.
# 19  Identifica si el paciente tiene un diagnóstico...
# 20  Identifica si el paciente tiene un diagnóstico...
# 21  Identifica si el paciente tiene un diagnóstico...
# 22  Identifica si el paciente presenta inmunosupre...
# 23  Identifica si el paciente tiene un diagnóstico...
# 24  Identifica si el paciente tiene diagnóstico de...
# 25  Identifica si el paciente tiene un diagnóstico...
# 26  Identifica si el paciente tiene diagnóstico de...
# 27  Identifica si el paciente tiene diagnóstico de...
# 28  Identifica si el paciente tiene hábito de taba...
# 29  Identifica si el paciente tuvo contacto con al...
# 30  Identifica el resultado del análisis de la mue...
# 31  Identifica si el paciente es una persona migra...
# 32           Identifica la nacionalidad del paciente.
# 33  Identifica el país del que partió el paciente ...
# 34  Identifica si el paciente requirió ingresar a ...
#
#                                      FORMATO O FUENTE
# 0                                          AAAA-MM-DD
# 1                                              TEXTO
# 2   CATALOGO: ORIGEN                              ...
# 3   CATALOGO: SECTOR                              ...
# 4                                 CATALOGO: ENTIDADES
# 5        CATALOGO: SEXO
# 6                                 CATALOGO: ENTIDADES
# 7                                 CATALOGO: ENTIDADES
# 8                                CATALOGO: MUNICIPIOS
# 9                            CATALOGO: TIPO_PACIENTE
# 10                                         AAAA-MM-DD
# 11                                         AAAA-MM-DD
# 12                                         AAAA-MM-DD
# 13  CATALOGO: SI_ NO                              ...
# 14  CATALOGO: SI_ NO                              ...
# 15                                   NÚMERICA EN AÑOS
# 16                            CATALOGO: NACIONALIDAD
# 17  CATALOGO: SI_ NO                              ...
# 18  CATALOGO: SI_ NO                              ...
# 19  CATALOGO: SI_ NO                              ...
# 20  CATALOGO: SI_ NO                              ...
# 21  CATALOGO: SI_ NO                              ...
# 22  CATALOGO: SI_ NO                              ...
# 23  CATALOGO: SI_ NO                              ...
# 24  CATALOGO: SI_ NO                              ...
# 25  CATALOGO: SI_ NO                              ...
# 26  CATALOGO: SI_ NO                              ...
# 27  CATALOGO: SI_ NO                              ...
# 28  CATALOGO: SI_ NO                              ...
# 29  CATALOGO: SI_ NO                              ...
# 30                                CATALOGO: RESULTADO
# 31  CATALOGO: SI_ NO                              ...
# 32                               TEXTO, 99= SE IGNORA
# 33                               TEXTO, 97= NO APLICA
# 34  CATALOGO: SI_ NO                              ...

# %%
total_dbs_columns=list(total_dbs.columns)

ORIGEN=[]
SECTOR=[]
SEXO=[]
TIPO_PACIENTE=[]
SI_NO=[]
NACIONALIDAD=[]
RESULTADO=[]
ENTIDADES=[]
MUNICIPIOS=[]

# %%
for c in range (len(total_dbs_columns)):
    #print(c)
    #print(total_dbs_columns[c])
    
    #Determina información en Columna Formato Fuente
    rFoF=Descriptores.loc[Descriptores["NOMBRE DE VARIABLE"]==total_dbs_columns[c],["FORMATO O FUENTE"]]
    FoF=rFoF["FORMATO O FUENTE"][c]
    
    #Si la información contiene Catalogo, entonces hace búsqueda del catálogo para traducir la información
    if "CATALOGO" in FoF:
        cat = rFoF["FORMATO O FUENTE"][c].split(": ",1)[1]
        cat=str(cat.replace(" ",""))
        #print(cat)
        
        if cat == "ORIGEN":
            ORIGEN.append(total_dbs_columns[c])
            #print(ORIGEN)
            
        elif cat == "SECTOR":
            SECTOR.append(total_dbs_columns[c])
            #print(SECTOR)
            
        elif cat =="SEXO":
            SEXO.append(total_dbs_columns[c])
            #print(SEXO)
        
        elif cat =="TIPO_PACIENTE":
            TIPO_PACIENTE.append(total_dbs_columns[c])
            #print(TIPO_PACIENTE)
            
        elif cat =="SI_NO":
            SI_NO.append(total_dbs_columns[c])
            #print(SI_NO)
        
        elif cat=="NACIONALIDAD":
            NACIONALIDAD.append(total_dbs_columns[c])
            #print(NACIONALIDAD)
        
        elif cat=="RESULTADO":
            RESULTADO.append(total_dbs_columns[c])
            #print(RESULTADO)
            
        elif cat=="ENTIDADES":
            ENTIDADES.append(total_dbs_columns[c])
            #print(ENTIDADES)
        
        elif cat=="MUNICIPIOS":
            MUNICIPIOS.append(total_dbs_columns[c])
            #print(MUNICIPIOS)

# %%
total_dbs_columns=list(total_dbs.columns)

for c in range (len(total_dbs_columns)):
    #print(c)
    print(total_dbs_columns[c])
    
    #Determina información en Columna Formato Fuente
    rFoF=Descriptores.loc[Descriptores["NOMBRE DE VARIABLE"]==total_dbs_columns[c],["FORMATO O FUENTE"]]
    FoF=rFoF["FORMATO O FUENTE"][c]
    
    #Si la información contiene Catalogo, entonces hace búsqueda del catálogo para traducir la información
    if "CATALOGO" in FoF:
        cat = rFoF["FORMATO O FUENTE"][c].split(": ",1)[1]        
        #print(cat)
        
        #Selecciona hoja de Catálogo para traducir información
        try:      
            sheet="Catálogo "+str(cat.replace(" ",""))
            dbcat=pd.read_excel("diccionario_datos_covid19/Catalogos_0412.xlsx",sheet_name=sheet)
            print("Existe Hoja:" + sheet)
            
            try:
                claves=dbcat.CLAVE.tolist()
                print("Existe CLAVE en " + sheet)
            except:
                try:
                    print("No existe CLAVE en " + sheet)
                    claves=dbcat.CLAVE_MUNICIPIO.tolist()
                except:
                    print("No existe CLAVE en " + sheet)
                    dbcat=pd.read_excel("diccionario_datos_covid19/Catalogos_0412.xlsx",sheet_name=sheet,skiprows=1)
                    claves=dbcat.CLAVE.tolist()
                    print("Existe CLAVE en " + sheet)
        
        except:
            print("No Existe Hoja: "+sheet)         
            sheet="Catálogo de "+str(cat.strip())
            dbcat=pd.read_excel("diccionario_datos_covid19/Catalogos_0412.xlsx",sheet_name=sheet)
            print("Existe Hoja: "+ sheet)
            
            claves=dbcat.CLAVE_ENTIDAD.tolist()
            print("Existe CLAVE_ENTIDAD en " + sheet)
        
        #Sustituye claves por descripciones, revisar con Merge
        #print(claves)
        for cl in range(len(claves)):
            
            try:
                total_dbs[total_dbs_columns[c]]=total_dbs[total_dbs_columns[c]].replace(dbcat["CLAVE"][cl],dbcat["DESCRIPCIÓN"][cl])
                print("Sustituido en " + total_dbs_columns[c])
                print(dbcat["CLAVE"][cl])
                print("con DESCRIPCIÓN " + dbcat["DESCRIPCIÓN"][cl])
            except:
                try:
                    total_dbs[total_dbs_columns[c]]=total_dbs[total_dbs_columns[c]].replace(dbcat["CLAVE_ENTIDAD"][cl],dbcat["ENTIDAD_FEDERATIVA"][cl])
                    print("Sustituido en " + total_dbs_columns[c])
                    print(dbcat["CLAVE_ENTIDAD"][cl])
                    print("con DESCRIPCIÓN " + dbcat["ENTIDAD_FEDERATIVA"][cl])
                except:
                    total_dbs[total_dbs_columns[c]]=total_dbs[total_dbs_columns[c]].replace(dbcat["CLAVE_MUNICIPIO"][cl],dbcat["MUNICIPIO"][cl])
                    print("Sustituido en " + total_dbs_columns[c])
                    print(dbcat["CLAVE_MUNICIPIO"][cl])
                    print("con DESCRIPCIÓN " + dbcat["MUNICIPIO"][cl])

#Hacer listas de columnas que corresponden a cada catálogo
#1. Definir qué catálogo requiere cada columna
#2. Agrupar columnas conforme al catálogo que utilizan
#3. Seleccionar valores de catálogo y sustituir en columnas que apliquen
# Out:
# FECHA_ACTUALIZACION
# ID_REGISTRO
# ORIGEN
# Existe Hoja:Catálogo ORIGEN
# Existe CLAVE en Catálogo ORIGEN
# Sustituido en ORIGEN
# 1
# con DESCRIPCIÓN USMER
# Sustituido en ORIGEN
# 2
# con DESCRIPCIÓN FUERA DE USMER
# Sustituido en ORIGEN
# 99
# con DESCRIPCIÓN NO ESPECIFICADO
# SECTOR
# Existe Hoja:Catálogo SECTOR
# Existe CLAVE en Catálogo SECTOR
# Sustituido en SECTOR
# 1
# con DESCRIPCIÓN CRUZ ROJA
# Sustituido en SECTOR
# 2
# con DESCRIPCIÓN DIF
# Sustituido en SECTOR
# 3
# con DESCRIPCIÓN ESTATAL
# Sustituido en SECTOR
# 4
# con DESCRIPCIÓN IMSS
# Sustituido en SECTOR
# 5
# con DESCRIPCIÓN IMSS-BIENESTAR
# Sustituido en SECTOR
# 6
# con DESCRIPCIÓN ISSSTE
# Sustituido en SECTOR
# 7
# con DESCRIPCIÓN MUNICIPAL
# Sustituido en SECTOR
# 8
# con DESCRIPCIÓN PEMEX
# Sustituido en SECTOR
# 9
# con DESCRIPCIÓN PRIVADA
# Sustituido en SECTOR
# 10
# con DESCRIPCIÓN SEDENA
# Sustituido en SECTOR
# 11
# con DESCRIPCIÓN SEMAR
# Sustituido en SECTOR
# 12
# con DESCRIPCIÓN SSA
# Sustituido en SECTOR
# 13
# con DESCRIPCIÓN UNIVERSITARIO
# Sustituido en SECTOR
# 99
# con DESCRIPCIÓN NO ESPECIFICADO
# ENTIDAD_UM
# No Existe Hoja: Catálogo ENTIDADES
# Existe Hoja: Catálogo de ENTIDADES
# Existe CLAVE_ENTIDAD en Catálogo de ENTIDADES
# Sustituido en ENTIDAD_UM
# 1
# con DESCRIPCIÓN AGUASCALIENTES
# Sustituido en ENTIDAD_UM
# 2
# con DESCRIPCIÓN BAJA CALIFORNIA
# Sustituido en ENTIDAD_UM
# 3
# con DESCRIPCIÓN BAJA CALIFORNIA SUR
# Sustituido en ENTIDAD_UM
# 4
# con DESCRIPCIÓN CAMPECHE
# Sustituido en ENTIDAD_UM
# 5
# con DESCRIPCIÓN COAHUILA DE ZARAGOZA
# Sustituido en ENTIDAD_UM
# 6
# con DESCRIPCIÓN COLIMA
# Sustituido en ENTIDAD_UM
# 7
# con DESCRIPCIÓN CHIAPAS
# Sustituido en ENTIDAD_UM
# 8
# con DESCRIPCIÓN CHIHUAHUA
# Sustituido en ENTIDAD_UM
# 9
# con DESCRIPCIÓN CIUDAD DE MÉXICO
# Sustituido en ENTIDAD_UM
# 10
# con DESCRIPCIÓN DURANGO
# Sustituido en ENTIDAD_UM
# 11
# con DESCRIPCIÓN GUANAJUATO
# Sustituido en ENTIDAD_UM
# 12
# con DESCRIPCIÓN GUERRERO
# Sustituido en ENTIDAD_UM
# 13
# con DESCRIPCIÓN HIDALGO
# Sustituido en ENTIDAD_UM
# 14
# con DESCRIPCIÓN JALISCO
# Sustituido en ENTIDAD_UM
# 15
# con DESCRIPCIÓN MÉXICO
# Sustituido en ENTIDAD_UM
# 16
# con DESCRIPCIÓN MICHOACÁN DE OCAMPO
# Sustituido en ENTIDAD_UM
# 17
# con DESCRIPCIÓN MORELOS
# Sustituido en ENTIDAD_UM
# 18
# con DESCRIPCIÓN NAYARIT
# Sustituido en ENTIDAD_UM
# 19
# con DESCRIPCIÓN NUEVO LEÓN
# Sustituido en ENTIDAD_UM
# 20
# con DESCRIPCIÓN OAXACA
# Sustituido en ENTIDAD_UM
# 21
# con DESCRIPCIÓN PUEBLA
# Sustituido en ENTIDAD_UM
# 22
# con DESCRIPCIÓN QUERÉTARO
# Sustituido en ENTIDAD_UM
# 23
# con DESCRIPCIÓN QUINTANA ROO
# Sustituido en ENTIDAD_UM
# 24
# con DESCRIPCIÓN SAN LUIS POTOSÍ
# Sustituido en ENTIDAD_UM
# 25
# con DESCRIPCIÓN SINALOA
# Sustituido en ENTIDAD_UM
# 26
# con DESCRIPCIÓN SONORA
# Sustituido en ENTIDAD_UM
# 27
# con DESCRIPCIÓN TABASCO
# Sustituido en ENTIDAD_UM
# 28
# con DESCRIPCIÓN TAMAULIPAS
# Sustituido en ENTIDAD_UM
# 29
# con DESCRIPCIÓN TLAXCALA
# Sustituido en ENTIDAD_UM
# 30
# con DESCRIPCIÓN VERACRUZ DE IGNACIO DE LA LLAVE
# Sustituido en ENTIDAD_UM
# 31
# con DESCRIPCIÓN YUCATÁN
# Sustituido en ENTIDAD_UM
# 32
# con DESCRIPCIÓN ZACATECAS
# Sustituido en ENTIDAD_UM
# 36
# con DESCRIPCIÓN ESTADOS UNIDOS MEXICANOS
# Sustituido en ENTIDAD_UM
# 97
# con DESCRIPCIÓN NO APLICA
# Sustituido en ENTIDAD_UM
# 98
# con DESCRIPCIÓN SE IGNORA
# Sustituido en ENTIDAD_UM
# 99
# con DESCRIPCIÓN NO ESPECIFICADO
# SEXO
# Existe Hoja:Catálogo SEXO
# Existe CLAVE en Catálogo SEXO
# Sustituido en SEXO
# 1
# con DESCRIPCIÓN MUJER
# Sustituido en SEXO
# 2
# con DESCRIPCIÓN HOMBRE
# Sustituido en SEXO
# 99
# con DESCRIPCIÓN NO ESPECIFICADO
# ENTIDAD_NAC
# No Existe Hoja: Catálogo ENTIDADES
# Existe Hoja: Catálogo de ENTIDADES
# Existe CLAVE_ENTIDAD en Catálogo de ENTIDADES
# Sustituido en ENTIDAD_NAC
# 1
# con DESCRIPCIÓN AGUASCALIENTES
# Sustituido en ENTIDAD_NAC
# 2
# con DESCRIPCIÓN BAJA CALIFORNIA
# Sustituido en ENTIDAD_NAC
# 3
# con DESCRIPCIÓN BAJA CALIFORNIA SUR
# Sustituido en ENTIDAD_NAC
# 4
# con DESCRIPCIÓN CAMPECHE
# Sustituido en ENTIDAD_NAC
# 5
# con DESCRIPCIÓN COAHUILA DE ZARAGOZA
# Sustituido en ENTIDAD_NAC
# 6
# con DESCRIPCIÓN COLIMA
# Sustituido en ENTIDAD_NAC
# 7
# con DESCRIPCIÓN CHIAPAS
# Sustituido en ENTIDAD_NAC
# 8
# con DESCRIPCIÓN CHIHUAHUA
# Sustituido en ENTIDAD_NAC
# 9
# con DESCRIPCIÓN CIUDAD DE MÉXICO
# Sustituido en ENTIDAD_NAC
# 10
# con DESCRIPCIÓN DURANGO
# Sustituido en ENTIDAD_NAC
# 11
# con DESCRIPCIÓN GUANAJUATO
# Sustituido en ENTIDAD_NAC
# 12
# con DESCRIPCIÓN GUERRERO
# Sustituido en ENTIDAD_NAC
# 13
# con DESCRIPCIÓN HIDALGO
# Sustituido en ENTIDAD_NAC
# 14
# con DESCRIPCIÓN JALISCO
# Sustituido en ENTIDAD_NAC
# 15
# con DESCRIPCIÓN MÉXICO
# Sustituido en ENTIDAD_NAC
# 16
# con DESCRIPCIÓN MICHOACÁN DE OCAMPO
# Sustituido en ENTIDAD_NAC
# 17
# con DESCRIPCIÓN MORELOS
# Sustituido en ENTIDAD_NAC
# 18
# con DESCRIPCIÓN NAYARIT
# Sustituido en ENTIDAD_NAC
# 19
# con DESCRIPCIÓN NUEVO LEÓN
# Sustituido en ENTIDAD_NAC
# 20
# con DESCRIPCIÓN OAXACA
# Sustituido en ENTIDAD_NAC
# 21
# con DESCRIPCIÓN PUEBLA
# Sustituido en ENTIDAD_NAC
# 22
# con DESCRIPCIÓN QUERÉTARO
# Sustituido en ENTIDAD_NAC
# 23
# con DESCRIPCIÓN QUINTANA ROO
# Sustituido en ENTIDAD_NAC
# 24
# con DESCRIPCIÓN SAN LUIS POTOSÍ
# Sustituido en ENTIDAD_NAC
# 25
# con DESCRIPCIÓN SINALOA
# Sustituido en ENTIDAD_NAC
# 26
# con DESCRIPCIÓN SONORA
# Sustituido en ENTIDAD_NAC
# 27
# con DESCRIPCIÓN TABASCO
# Sustituido en ENTIDAD_NAC
# 28
# con DESCRIPCIÓN TAMAULIPAS
# Sustituido en ENTIDAD_NAC
# 29
# con DESCRIPCIÓN TLAXCALA
# Sustituido en ENTIDAD_NAC
# 30
# con DESCRIPCIÓN VERACRUZ DE IGNACIO DE LA LLAVE
# Sustituido en ENTIDAD_NAC
# 31
# con DESCRIPCIÓN YUCATÁN
# Sustituido en ENTIDAD_NAC
# 32
# con DESCRIPCIÓN ZACATECAS
# Sustituido en ENTIDAD_NAC
# 36
# con DESCRIPCIÓN ESTADOS UNIDOS MEXICANOS
# Sustituido en ENTIDAD_NAC
# 97
# con DESCRIPCIÓN NO APLICA
# Sustituido en ENTIDAD_NAC
# 98
# con DESCRIPCIÓN SE IGNORA
# Sustituido en ENTIDAD_NAC
# 99
# con DESCRIPCIÓN NO ESPECIFICADO
# ENTIDAD_RES
# No Existe Hoja: Catálogo ENTIDADES
# Existe Hoja: Catálogo de ENTIDADES
# Existe CLAVE_ENTIDAD en Catálogo de ENTIDADES
# Sustituido en ENTIDAD_RES
# 1
# con DESCRIPCIÓN AGUASCALIENTES
# Sustituido en ENTIDAD_RES
# 2
# con DESCRIPCIÓN BAJA CALIFORNIA
# Sustituido en ENTIDAD_RES
# 3
# con DESCRIPCIÓN BAJA CALIFORNIA SUR
# Sustituido en ENTIDAD_RES
# 4
# con DESCRIPCIÓN CAMPECHE
# Sustituido en ENTIDAD_RES
# 5
# con DESCRIPCIÓN COAHUILA DE ZARAGOZA
# Sustituido en ENTIDAD_RES
# 6
# con DESCRIPCIÓN COLIMA
# Sustituido en ENTIDAD_RES
# 7
# con DESCRIPCIÓN CHIAPAS
# Sustituido en ENTIDAD_RES
# 8
# con DESCRIPCIÓN CHIHUAHUA
# Sustituido en ENTIDAD_RES
# 9
# con DESCRIPCIÓN CIUDAD DE MÉXICO
# Sustituido en ENTIDAD_RES
# 10
# con DESCRIPCIÓN DURANGO
# Sustituido en ENTIDAD_RES
# 11
# con DESCRIPCIÓN GUANAJUATO
# Sustituido en ENTIDAD_RES
# 12
# con DESCRIPCIÓN GUERRERO
# Sustituido en ENTIDAD_RES
# 13
# con DESCRIPCIÓN HIDALGO
# Sustituido en ENTIDAD_RES
# 14
# con DESCRIPCIÓN JALISCO
# Sustituido en ENTIDAD_RES
# 15
# con DESCRIPCIÓN MÉXICO
# Sustituido en ENTIDAD_RES
# 16
# con DESCRIPCIÓN MICHOACÁN DE OCAMPO
# Sustituido en ENTIDAD_RES
# 17
# con DESCRIPCIÓN MORELOS
# Sustituido en ENTIDAD_RES
# 18
# con DESCRIPCIÓN NAYARIT
# Sustituido en ENTIDAD_RES
# 19
# con DESCRIPCIÓN NUEVO LEÓN
# Sustituido en ENTIDAD_RES
# 20
# con DESCRIPCIÓN OAXACA
# Sustituido en ENTIDAD_RES
# 21
# con DESCRIPCIÓN PUEBLA
# Sustituido en ENTIDAD_RES
# 22
# con DESCRIPCIÓN QUERÉTARO
# Sustituido en ENTIDAD_RES
# 23
# con DESCRIPCIÓN QUINTANA ROO
# Sustituido en ENTIDAD_RES
# 24
# con DESCRIPCIÓN SAN LUIS POTOSÍ
# Sustituido en ENTIDAD_RES
# 25
# con DESCRIPCIÓN SINALOA
# Sustituido en ENTIDAD_RES
# 26
# con DESCRIPCIÓN SONORA
# Sustituido en ENTIDAD_RES
# 27
# con DESCRIPCIÓN TABASCO
# Sustituido en ENTIDAD_RES
# 28
# con DESCRIPCIÓN TAMAULIPAS
# Sustituido en ENTIDAD_RES
# 29
# con DESCRIPCIÓN TLAXCALA
# Sustituido en ENTIDAD_RES
# 30
# con DESCRIPCIÓN VERACRUZ DE IGNACIO DE LA LLAVE
# Sustituido en ENTIDAD_RES
# 31
# con DESCRIPCIÓN YUCATÁN
# Sustituido en ENTIDAD_RES
# 32
# con DESCRIPCIÓN ZACATECAS
# Sustituido en ENTIDAD_RES
# 36
# con DESCRIPCIÓN ESTADOS UNIDOS MEXICANOS
# Sustituido en ENTIDAD_RES
# 97
# con DESCRIPCIÓN NO APLICA
# Sustituido en ENTIDAD_RES
# 98
# con DESCRIPCIÓN SE IGNORA
# Sustituido en ENTIDAD_RES
# 99
# con DESCRIPCIÓN NO ESPECIFICADO
# MUNICIPIO_RES
# Existe Hoja:Catálogo MUNICIPIOS
# No existe CLAVE en Catálogo MUNICIPIOS
# Sustituido en MUNICIPIO_RES
# 1
# con DESCRIPCIÓN AGUASCALIENTES
# Sustituido en MUNICIPIO_RES
# 2
# con DESCRIPCIÓN ASIENTOS
# Sustituido en MUNICIPIO_RES
# 3
# con DESCRIPCIÓN CALVILLO
# Sustituido en MUNICIPIO_RES
# 4
# con DESCRIPCIÓN COSÍO
# Sustituido en MUNICIPIO_RES
# 5
# con DESCRIPCIÓN JESÚS MARÍA
# Sustituido en MUNICIPIO_RES
# 6
# con DESCRIPCIÓN PABELLÓN DE ARTEAGA
# Sustituido en MUNICIPIO_RES
# 7
# con DESCRIPCIÓN RINCÓN DE ROMOS
# Sustituido en MUNICIPIO_RES
# 8
# con DESCRIPCIÓN SAN JOSÉ DE GRACIA
# Sustituido en MUNICIPIO_RES
# 9
# con DESCRIPCIÓN TEPEZALÁ
# Sustituido en MUNICIPIO_RES
# 10
# con DESCRIPCIÓN EL LLANO
# Sustituido en MUNICIPIO_RES
# 11
# con DESCRIPCIÓN SAN FRANCISCO DE LOS ROMO
# Sustituido en MUNICIPIO_RES
# 999
# con DESCRIPCIÓN NO ESPECIFICADO
# Sustituido en MUNICIPIO_RES
# 1
# con DESCRIPCIÓN ENSENADA
# Sustituido en MUNICIPIO_RES
# 2
# con DESCRIPCIÓN MEXICALI
# Sustituido en MUNICIPIO_RES
# 3
# con DESCRIPCIÓN TECATE
# Sustituido en MUNICIPIO_RES
# 4
# con DESCRIPCIÓN TIJUANA
# Sustituido en MUNICIPIO_RES
# 5
# con DESCRIPCIÓN PLAYAS DE ROSARITO
# Sustituido en MUNICIPIO_RES
# 999
# con DESCRIPCIÓN NO ESPECIFICADO
# Sustituido en MUNICIPIO_RES
# 1
# con DESCRIPCIÓN COMONDÚ
# Sustituido en MUNICIPIO_RES
# 2
# con DESCRIPCIÓN MULEGÉ
# Sustituido en MUNICIPIO_RES
# 3
# con DESCRIPCIÓN LA PAZ
# Sustituido en MUNICIPIO_RES
# 8
# con DESCRIPCIÓN LOS CABOS
# Sustituido en MUNICIPIO_RES
# 9
# con DESCRIPCIÓN LORETO
# Sustituido en MUNICIPIO_RES
# 999
# con DESCRIPCIÓN NO ESPECIFICADO
# Sustituido en MUNICIPIO_RES
# 1
# con DESCRIPCIÓN CALKINÍ
# Sustituido en MUNICIPIO_RES
# 2
# con DESCRIPCIÓN CAMPECHE
# Sustituido en MUNICIPIO_RES
# 3
# con DESCRIPCIÓN CARMEN
# Sustituido en MUNICIPIO_RES
# 4
# con DESCRIPCIÓN CHAMPOTÓN
# Sustituido en MUNICIPIO_RES
# 5
# con DESCRIPCIÓN HECELCHAKÁN
# Sustituido en MUNICIPIO_RES
# 6
# con DESCRIPCIÓN HOPELCHÉN
# Sustituido en MUNICIPIO_RES
# 7
# con DESCRIPCIÓN PALIZADA
# Sustituido en MUNICIPIO_RES
# 8
# con DESCRIPCIÓN TENABO
# Sustituido en MUNICIPIO_RES
# 9
# con DESCRIPCIÓN ESCÁRCEGA
# Sustituido en MUNICIPIO_RES
# 10
# con DESCRIPCIÓN CALAKMUL
# Sustituido en MUNICIPIO_RES
# 11
# con DESCRIPCIÓN CANDELARIA
# Sustituido en MUNICIPIO_RES
# 999
# con DESCRIPCIÓN NO ESPECIFICADO
# Sustituido en MUNICIPIO_RES
# 1
# con DESCRIPCIÓN ABASOLO
# Sustituido en MUNICIPIO_RES
# 2
# con DESCRIPCIÓN ACUÑA
# Sustituido en MUNICIPIO_RES
# 3
# con DESCRIPCIÓN ALLENDE
# Sustituido en MUNICIPIO_RES
# 4
# con DESCRIPCIÓN ARTEAGA
# Sustituido en MUNICIPIO_RES
# 5
# con DESCRIPCIÓN CANDELA
# Sustituido en MUNICIPIO_RES
# 6
# con DESCRIPCIÓN CASTAÑOS
# Sustituido en MUNICIPIO_RES
# 7
# con DESCRIPCIÓN CUATRO CIÉNEGAS
# Sustituido en MUNICIPIO_RES
# 8
# con DESCRIPCIÓN ESCOBEDO
# Sustituido en MUNICIPIO_RES
# 9
# con DESCRIPCIÓN FRANCISCO I. MADERO
# Sustituido en MUNICIPIO_RES
# 10
# con DESCRIPCIÓN FRONTERA
# Sustituido en MUNICIPIO_RES
# 11
# con DESCRIPCIÓN GENERAL CEPEDA
# Sustituido en MUNICIPIO_RES
# 12
# con DESCRIPCIÓN GUERRERO
# Sustituido en MUNICIPIO_RES
# 13
# con DESCRIPCIÓN HIDALGO
# Sustituido en MUNICIPIO_RES
# 14
# con DESCRIPCIÓN JIMÉNEZ
# Sustituido en MUNICIPIO_RES
# 15
# con DESCRIPCIÓN JUÁREZ
# Sustituido en MUNICIPIO_RES
# 16
# con DESCRIPCIÓN LAMADRID
# Sustituido en MUNICIPIO_RES
# 17
# con DESCRIPCIÓN MATAMOROS
# Sustituido en MUNICIPIO_RES
# 18
# con DESCRIPCIÓN MONCLOVA
# Sustituido en MUNICIPIO_RES
# 19
# con DESCRIPCIÓN MORELOS
# Sustituido en MUNICIPIO_RES
# 20
# con DESCRIPCIÓN MÚZQUIZ
# Sustituido en MUNICIPIO_RES
# 21
# con DESCRIPCIÓN NADADORES
# Sustituido en MUNICIPIO_RES
# 22
# con DESCRIPCIÓN NAVA
# Sustituido en MUNICIPIO_RES
# 23
# con DESCRIPCIÓN OCAMPO
# Sustituido en MUNICIPIO_RES
# 24
# con DESCRIPCIÓN PARRAS
# Sustituido en MUNICIPIO_RES
# 25
# con DESCRIPCIÓN PIEDRAS NEGRAS
# Sustituido en MUNICIPIO_RES
# 26
# con DESCRIPCIÓN PROGRESO
# Sustituido en MUNICIPIO_RES
# 27
# con DESCRIPCIÓN RAMOS ARIZPE
# Sustituido en MUNICIPIO_RES
# 28
# con DESCRIPCIÓN SABINAS
# Sustituido en MUNICIPIO_RES
# 29
# con DESCRIPCIÓN SACRAMENTO
# Sustituido en MUNICIPIO_RES
# 30
# con DESCRIPCIÓN SALTILLO
# Sustituido en MUNICIPIO_RES
# 31
# con DESCRIPCIÓN SAN BUENAVENTURA
# Sustituido en MUNICIPIO_RES
# 32
# con DESCRIPCIÓN SAN JUAN DE SABINAS
# Sustituido en MUNICIPIO_RES
# 33
# con DESCRIPCIÓN SAN PEDRO
# Sustituido en MUNICIPIO_RES
# 34
# con DESCRIPCIÓN SIERRA MOJADA
# Sustituido en MUNICIPIO_RES
# 35
# con DESCRIPCIÓN TORREÓN
# Sustituido en MUNICIPIO_RES
# 36
# con DESCRIPCIÓN VIESCA
# Sustituido en MUNICIPIO_RES
# 37
# con DESCRIPCIÓN VILLA UNIÓN
# Sustituido en MUNICIPIO_RES
# 38
# con DESCRIPCIÓN ZARAGOZA
# Sustituido en MUNICIPIO_RES
# 999
# con DESCRIPCIÓN NO ESPECIFICADO
# Sustituido en MUNICIPIO_RES
# 1
# con DESCRIPCIÓN ARMERÍA
# Sustituido en MUNICIPIO_RES
# 2
# con DESCRIPCIÓN COLIMA
# Sustituido en MUNICIPIO_RES
# 3
# con DESCRIPCIÓN COMALA
# Sustituido en MUNICIPIO_RES
# 4
# con DESCRIPCIÓN COQUIMATLÁN
# Sustituido en MUNICIPIO_RES
# 5
# con DESCRIPCIÓN CUAUHTÉMOC
# Sustituido en MUNICIPIO_RES
# 6
# con DESCRIPCIÓN IXTLAHUACÁN
# Sustituido en MUNICIPIO_RES
# 7
# con DESCRIPCIÓN MANZANILLO
# Sustituido en MUNICIPIO_RES
# 8
# con DESCRIPCIÓN MINATITLÁN
# Sustituido en MUNICIPIO_RES
# 9
# con DESCRIPCIÓN TECOMÁN
# Sustituido en MUNICIPIO_RES
# 10
# con DESCRIPCIÓN VILLA DE ÁLVAREZ
# Sustituido en MUNICIPIO_RES
# 999
# con DESCRIPCIÓN NO ESPECIFICADO
# Sustituido en MUNICIPIO_RES
# 1
# con DESCRIPCIÓN ACACOYAGUA
# Sustituido en MUNICIPIO_RES
# 2
# con DESCRIPCIÓN ACALA
# Sustituido en MUNICIPIO_RES
# 3
# con DESCRIPCIÓN ACAPETAHUA
# Sustituido en MUNICIPIO_RES
# 4
# con DESCRIPCIÓN ALTAMIRANO
# Sustituido en MUNICIPIO_RES
# 5
# con DESCRIPCIÓN AMATÁN
# Sustituido en MUNICIPIO_RES
# 6
# con DESCRIPCIÓN AMATENANGO DE LA FRONTERA
# Sustituido en MUNICIPIO_RES
# 7
# con DESCRIPCIÓN AMATENANGO DEL VALLE
# Sustituido en MUNICIPIO_RES
# 8
# con DESCRIPCIÓN ANGEL ALBINO CORZO
# Sustituido en MUNICIPIO_RES
# 9
# con DESCRIPCIÓN ARRIAGA
# Sustituido en MUNICIPIO_RES
# 10
# con DESCRIPCIÓN BEJUCAL DE OCAMPO
# Sustituido en MUNICIPIO_RES
# 11
# con DESCRIPCIÓN BELLA VISTA
# Sustituido en MUNICIPIO_RES
# 12
# con DESCRIPCIÓN BERRIOZÁBAL
# Sustituido en MUNICIPIO_RES
# 13
# con DESCRIPCIÓN BOCHIL
# Sustituido en MUNICIPIO_RES
# 14
# con DESCRIPCIÓN EL BOSQUE
# Sustituido en MUNICIPIO_RES
# 15
# con DESCRIPCIÓN CACAHOATÁN
# Sustituido en MUNICIPIO_RES
# 16
# con DESCRIPCIÓN CATAZAJÁ
# Sustituido en MUNICIPIO_RES
# 17
# con DESCRIPCIÓN CINTALAPA
# Sustituido en MUNICIPIO_RES
# 18
# con DESCRIPCIÓN COAPILLA
# Sustituido en MUNICIPIO_RES
# 19
# con DESCRIPCIÓN COMITÁN DE DOMÍNGUEZ
# Sustituido en MUNICIPIO_RES
# 20
# con DESCRIPCIÓN LA CONCORDIA
# Sustituido en MUNICIPIO_RES
# 21
# con DESCRIPCIÓN COPAINALÁ
# Sustituido en MUNICIPIO_RES
# 22
# con DESCRIPCIÓN CHALCHIHUITÁN
# Sustituido en MUNICIPIO_RES
# 23
# con DESCRIPCIÓN CHAMULA
# Sustituido en MUNICIPIO_RES
# 24
# con DESCRIPCIÓN CHANAL
# Sustituido en MUNICIPIO_RES
# 25
# con DESCRIPCIÓN CHAPULTENANGO
# Sustituido en MUNICIPIO_RES
# 26
# con DESCRIPCIÓN CHENALHÓ
# Sustituido en MUNICIPIO_RES
# 27
# con DESCRIPCIÓN CHIAPA DE CORZO
# Sustituido en MUNICIPIO_RES
# 28
# con DESCRIPCIÓN CHIAPILLA
# Sustituido en MUNICIPIO_RES
# 29
# con DESCRIPCIÓN CHICOASÉN
# Sustituido en MUNICIPIO_RES
# 30
# con DESCRIPCIÓN CHICOMUSELO
# Sustituido en MUNICIPIO_RES
# 31
# con DESCRIPCIÓN CHILÓN
# Sustituido en MUNICIPIO_RES
# 32
# con DESCRIPCIÓN ESCUINTLA
# Sustituido en MUNICIPIO_RES
# 33
# con DESCRIPCIÓN FRANCISCO LEÓN
# Sustituido en MUNICIPIO_RES
# 34
# con DESCRIPCIÓN FRONTERA COMALAPA
# Sustituido en MUNICIPIO_RES
# 35
# con DESCRIPCIÓN FRONTERA HIDALGO
# Sustituido en MUNICIPIO_RES
# 36
# con DESCRIPCIÓN LA GRANDEZA
# Sustituido en MUNICIPIO_RES
# 37
# con DESCRIPCIÓN HUEHUETÁN
# Sustituido en MUNICIPIO_RES
# 38
# con DESCRIPCIÓN HUIXTÁN
# Sustituido en MUNICIPIO_RES
# 39
# con DESCRIPCIÓN HUITIUPÁN
# Sustituido en MUNICIPIO_RES
# 40
# con DESCRIPCIÓN HUIXTLA
# Sustituido en MUNICIPIO_RES
# 41
# con DESCRIPCIÓN LA INDEPENDENCIA
# Sustituido en MUNICIPIO_RES
# 42
# con DESCRIPCIÓN IXHUATÁN
# Sustituido en MUNICIPIO_RES
# 43
# con DESCRIPCIÓN IXTACOMITÁN
# Sustituido en MUNICIPIO_RES
# 44
# con DESCRIPCIÓN IXTAPA
# Sustituido en MUNICIPIO_RES
# 45
# con DESCRIPCIÓN IXTAPANGAJOYA
# Sustituido en MUNICIPIO_RES
# 46
# con DESCRIPCIÓN JIQUIPILAS
# Sustituido en MUNICIPIO_RES
# 47
# con DESCRIPCIÓN JITOTOL
# Sustituido en MUNICIPIO_RES
# 48
# con DESCRIPCIÓN JUÁREZ
# Sustituido en MUNICIPIO_RES
# 49
# con DESCRIPCIÓN LARRÁINZAR
# Sustituido en MUNICIPIO_RES
# 50
# con DESCRIPCIÓN LA LIBERTAD
# Sustituido en MUNICIPIO_RES
# 51
# con DESCRIPCIÓN MAPASTEPEC
# Sustituido en MUNICIPIO_RES
# 52
# con DESCRIPCIÓN LAS MARGARITAS
# Sustituido en MUNICIPIO_RES
# 53
# con DESCRIPCIÓN MAZAPA DE MADERO
# Sustituido en MUNICIPIO_RES
# 54
# con DESCRIPCIÓN MAZATÁN
# Sustituido en MUNICIPIO_RES
# 55
# con DESCRIPCIÓN METAPA
# Sustituido en MUNICIPIO_RES
# 56
# con DESCRIPCIÓN MITONTIC
# Sustituido en MUNICIPIO_RES
# 57
# con DESCRIPCIÓN MOTOZINTLA
# Sustituido en MUNICIPIO_RES
# 58
# con DESCRIPCIÓN NICOLÁS RUÍZ
# Sustituido en MUNICIPIO_RES
# 59
# con DESCRIPCIÓN OCOSINGO
# Sustituido en MUNICIPIO_RES
# 60
# con DESCRIPCIÓN OCOTEPEC
# Sustituido en MUNICIPIO_RES
# 61
# con DESCRIPCIÓN OCOZOCOAUTLA DE ESPINOSA
# Sustituido en MUNICIPIO_RES
# 62
# con DESCRIPCIÓN OSTUACÁN
# Sustituido en MUNICIPIO_RES
# 63
# con DESCRIPCIÓN OSUMACINTA
# Sustituido en MUNICIPIO_RES
# 64
# con DESCRIPCIÓN OXCHUC
# Sustituido en MUNICIPIO_RES
# 65
# con DESCRIPCIÓN PALENQUE
# Sustituido en MUNICIPIO_RES
# 66
# con DESCRIPCIÓN PANTELHÓ
# Sustituido en MUNICIPIO_RES
# 67
# con DESCRIPCIÓN PANTEPEC
# Sustituido en MUNICIPIO_RES
# 68
# con DESCRIPCIÓN PICHUCALCO
# Sustituido en MUNICIPIO_RES
# 69
# con DESCRIPCIÓN PIJIJIAPAN
# Sustituido en MUNICIPIO_RES
# 70
# con DESCRIPCIÓN EL PORVENIR
# Sustituido en MUNICIPIO_RES
# 71
# con DESCRIPCIÓN VILLA COMALTITLÁN
# Sustituido en MUNICIPIO_RES
# 72
# con DESCRIPCIÓN PUEBLO NUEVO SOLISTAHUACÁN
# Sustituido en MUNICIPIO_RES
# 73
# con DESCRIPCIÓN RAYÓN
# Sustituido en MUNICIPIO_RES
# 74
# con DESCRIPCIÓN REFORMA
# Sustituido en MUNICIPIO_RES
# 75
# con DESCRIPCIÓN LAS ROSAS
# Sustituido en MUNICIPIO_RES
# 76
# con DESCRIPCIÓN SABANILLA
# Sustituido en MUNICIPIO_RES
# 77
# con DESCRIPCIÓN SALTO DE AGUA
# Sustituido en MUNICIPIO_RES
# 78
# con DESCRIPCIÓN SAN CRISTÓBAL DE LAS CASAS
# Sustituido en MUNICIPIO_RES
# 79
# con DESCRIPCIÓN SAN FERNANDO
# Sustituido en MUNICIPIO_RES
# 80
# con DESCRIPCIÓN SILTEPEC
# Sustituido en MUNICIPIO_RES
# 81
# con DESCRIPCIÓN SIMOJOVEL
# Sustituido en MUNICIPIO_RES
# 82
# con DESCRIPCIÓN SITALÁ
# Sustituido en MUNICIPIO_RES
# 83
# con DESCRIPCIÓN SOCOLTENANGO
# Sustituido en MUNICIPIO_RES
# 84
# con DESCRIPCIÓN SOLOSUCHIAPA
# Sustituido en MUNICIPIO_RES
# 85
# con DESCRIPCIÓN SOYALÓ
# Sustituido en MUNICIPIO_RES
# 86
# con DESCRIPCIÓN SUCHIAPA
# Sustituido en MUNICIPIO_RES
# 87
# con DESCRIPCIÓN SUCHIATE
# Sustituido en MUNICIPIO_RES
# 88
# con DESCRIPCIÓN SUNUAPA
# Sustituido en MUNICIPIO_RES
# 89
# con DESCRIPCIÓN TAPACHULA
# Sustituido en MUNICIPIO_RES
# 90
# con DESCRIPCIÓN TAPALAPA
# Sustituido en MUNICIPIO_RES
# 91
# con DESCRIPCIÓN TAPILULA
# Sustituido en MUNICIPIO_RES
# 92
# con DESCRIPCIÓN TECPATÁN
# Sustituido en MUNICIPIO_RES
# 93
# con DESCRIPCIÓN TENEJAPA
# Sustituido en MUNICIPIO_RES
# 94
# con DESCRIPCIÓN TEOPISCA
# Sustituido en MUNICIPIO_RES
# 96
# con DESCRIPCIÓN TILA
# Sustituido en MUNICIPIO_RES
# 97
# con DESCRIPCIÓN TONALÁ
# Sustituido en MUNICIPIO_RES
# 98
# con DESCRIPCIÓN TOTOLAPA
# Sustituido en MUNICIPIO_RES
# 99
# con DESCRIPCIÓN LA TRINITARIA
# Sustituido en MUNICIPIO_RES
# 100
# con DESCRIPCIÓN TUMBALÁ
# Sustituido en MUNICIPIO_RES
# 101
# con DESCRIPCIÓN TUXTLA GUTIÉRREZ
# Sustituido en MUNICIPIO_RES
# 102
# con DESCRIPCIÓN TUXTLA CHICO
# Sustituido en MUNICIPIO_RES
# 103
# con DESCRIPCIÓN TUZANTÁN
# Sustituido en MUNICIPIO_RES
# 104
# con DESCRIPCIÓN TZIMOL
# Sustituido en MUNICIPIO_RES
# 105
# con DESCRIPCIÓN UNIÓN JUÁREZ
# Sustituido en MUNICIPIO_RES
# 106
# con DESCRIPCIÓN VENUSTIANO CARRANZA
# Sustituido en MUNICIPIO_RES
# 107
# con DESCRIPCIÓN VILLA CORZO
# Sustituido en MUNICIPIO_RES
# 108
# con DESCRIPCIÓN VILLAFLORES
# Sustituido en MUNICIPIO_RES
# 109
# con DESCRIPCIÓN YAJALÓN
# Sustituido en MUNICIPIO_RES
# 110
# con DESCRIPCIÓN SAN LUCAS
# Sustituido en MUNICIPIO_RES
# 111
# con DESCRIPCIÓN ZINACANTÁN
# Sustituido en MUNICIPIO_RES
# 112
# con DESCRIPCIÓN SAN JUAN CANCUC
# Sustituido en MUNICIPIO_RES
# 113
# con DESCRIPCIÓN ALDAMA
# Sustituido en MUNICIPIO_RES
# 114
# con DESCRIPCIÓN BENEMÉRITO DE LAS AMÉRICAS
# Sustituido en MUNICIPIO_RES
# 115
# con DESCRIPCIÓN MARAVILLA TENEJAPA
# Sustituido en MUNICIPIO_RES
# 116
# con DESCRIPCIÓN MARQUÉS DE COMILLAS
# Sustituido en MUNICIPIO_RES
# 117
# con DESCRIPCIÓN MONTECRISTO DE GUERRERO
# Sustituido en MUNICIPIO_RES
# 118
# con DESCRIPCIÓN SAN ANDRÉS DURAZNAL
# Sustituido en MUNICIPIO_RES
# 119
# con DESCRIPCIÓN SANTIAGO EL PINAR
# Sustituido en MUNICIPIO_RES
# 120
# con DESCRIPCIÓN CAPITÁN LUIS ÁNGEL VIDAL
# Sustituido en MUNICIPIO_RES
# 121
# con DESCRIPCIÓN RINCÓN CHAMULA SAN PEDRO
# Sustituido en MUNICIPIO_RES
# 122
# con DESCRIPCIÓN EL PARRAL
# Sustituido en MUNICIPIO_RES
# 123
# con DESCRIPCIÓN EMILIANO ZAPATA
# Sustituido en MUNICIPIO_RES
# 124
# con DESCRIPCIÓN MEZCALAPA
# Sustituido en MUNICIPIO_RES
# 999
# con DESCRIPCIÓN NO ESPECIFICADO
# Sustituido en MUNICIPIO_RES
# 1
# con DESCRIPCIÓN AHUMADA
# Sustituido en MUNICIPIO_RES
# 2
# con DESCRIPCIÓN ALDAMA
# Sustituido en MUNICIPIO_RES
# 3
# con DESCRIPCIÓN ALLENDE
# Sustituido en MUNICIPIO_RES
# 4
# con DESCRIPCIÓN AQUILES SERDÁN
# Sustituido en MUNICIPIO_RES
# 5
# con DESCRIPCIÓN ASCENSIÓN
# Sustituido en MUNICIPIO_RES
# 6
# con DESCRIPCIÓN BACHÍNIVA
# Sustituido en MUNICIPIO_RES
# 7
# con DESCRIPCIÓN BALLEZA
# Sustituido en MUNICIPIO_RES
# 8
# con DESCRIPCIÓN BATOPILAS DE MANUEL GÓMEZ MORÍN
# Sustituido en MUNICIPIO_RES
# 9
# con DESCRIPCIÓN BOCOYNA
# Sustituido en MUNICIPIO_RES
# 10
# con DESCRIPCIÓN BUENAVENTURA
# Sustituido en MUNICIPIO_RES
# 11
# con DESCRIPCIÓN CAMARGO
# Sustituido en MUNICIPIO_RES
# 12
# con DESCRIPCIÓN CARICHÍ
# Sustituido en MUNICIPIO_RES
# 13
# con DESCRIPCIÓN CASAS GRANDES
# Sustituido en MUNICIPIO_RES
# 14
# con DESCRIPCIÓN CORONADO
# Sustituido en MUNICIPIO_RES
# 15
# con DESCRIPCIÓN COYAME DEL SOTOL
# Sustituido en MUNICIPIO_RES
# 16
# con DESCRIPCIÓN LA CRUZ
# Sustituido en MUNICIPIO_RES
# 17
# con DESCRIPCIÓN CUAUHTÉMOC
# Sustituido en MUNICIPIO_RES
# 18
# con DESCRIPCIÓN CUSIHUIRIACHI
# Sustituido en MUNICIPIO_RES
# 19
# con DESCRIPCIÓN CHIHUAHUA
# Sustituido en MUNICIPIO_RES
# 20
# con DESCRIPCIÓN CHÍNIPAS
# Sustituido en MUNICIPIO_RES
# 21
# con DESCRIPCIÓN DELICIAS
# Sustituido en MUNICIPIO_RES
# 22
# con DESCRIPCIÓN DR. BELISARIO DOMÍNGUEZ
# Sustituido en MUNICIPIO_RES
# 23
# con DESCRIPCIÓN GALEANA
# Sustituido en MUNICIPIO_RES
# 24
# con DESCRIPCIÓN SANTA ISABEL
# Sustituido en MUNICIPIO_RES
# 25
# con DESCRIPCIÓN GÓMEZ FARÍAS
# Sustituido en MUNICIPIO_RES
# 26
# con DESCRIPCIÓN GRAN MORELOS
# Sustituido en MUNICIPIO_RES
# 27
# con DESCRIPCIÓN GUACHOCHI
# Sustituido en MUNICIPIO_RES
# 28
# con DESCRIPCIÓN GUADALUPE
# Sustituido en MUNICIPIO_RES
# 29
# con DESCRIPCIÓN GUADALUPE Y CALVO
# Sustituido en MUNICIPIO_RES
# 30
# con DESCRIPCIÓN GUAZAPARES
# Sustituido en MUNICIPIO_RES
# 31
# con DESCRIPCIÓN GUERRERO
# Sustituido en MUNICIPIO_RES
# 32
# con DESCRIPCIÓN HIDALGO DEL PARRAL
# Sustituido en MUNICIPIO_RES
# 33
# con DESCRIPCIÓN HUEJOTITÁN
# Sustituido en MUNICIPIO_RES
# 34
# con DESCRIPCIÓN IGNACIO ZARAGOZA
# Sustituido en MUNICIPIO_RES
# 35
# con DESCRIPCIÓN JANOS
# Sustituido en MUNICIPIO_RES
# 36
# con DESCRIPCIÓN JIMÉNEZ
# Sustituido en MUNICIPIO_RES
# 37
# con DESCRIPCIÓN JUÁREZ
# Sustituido en MUNICIPIO_RES
# 38
# con DESCRIPCIÓN JULIMES
# Sustituido en MUNICIPIO_RES
# 39
# con DESCRIPCIÓN LÓPEZ
# Sustituido en MUNICIPIO_RES
# 40
# con DESCRIPCIÓN MADERA
# Sustituido en MUNICIPIO_RES
# 41
# con DESCRIPCIÓN MAGUARICHI
# Sustituido en MUNICIPIO_RES
# 42
# con DESCRIPCIÓN MANUEL BENAVIDES
# Sustituido en MUNICIPIO_RES
# 43
# con DESCRIPCIÓN MATACHÍ
# Sustituido en MUNICIPIO_RES
# 44
# con DESCRIPCIÓN MATAMOROS
# Sustituido en MUNICIPIO_RES
# 45
# con DESCRIPCIÓN MEOQUI
# Sustituido en MUNICIPIO_RES
# 46
# con DESCRIPCIÓN MORELOS
# Sustituido en MUNICIPIO_RES
# 47
# con DESCRIPCIÓN MORIS
# Sustituido en MUNICIPIO_RES
# 48
# con DESCRIPCIÓN NAMIQUIPA
# Sustituido en MUNICIPIO_RES
# 49
# con DESCRIPCIÓN NONOAVA
# Sustituido en MUNICIPIO_RES
# 50
# con DESCRIPCIÓN NUEVO CASAS GRANDES
# Sustituido en MUNICIPIO_RES
# 51
# con DESCRIPCIÓN OCAMPO
# Sustituido en MUNICIPIO_RES
# 52
# con DESCRIPCIÓN OJINAGA
# Sustituido en MUNICIPIO_RES
# 53
# con DESCRIPCIÓN PRAXEDIS G. GUERRERO
# Sustituido en MUNICIPIO_RES
# 54
# con DESCRIPCIÓN RIVA PALACIO
# Sustituido en MUNICIPIO_RES
# 55
# con DESCRIPCIÓN ROSALES
# Sustituido en MUNICIPIO_RES
# 56
# con DESCRIPCIÓN ROSARIO
# Sustituido en MUNICIPIO_RES
# 57
# con DESCRIPCIÓN SAN FRANCISCO DE BORJA
# Sustituido en MUNICIPIO_RES
# 58
# con DESCRIPCIÓN SAN FRANCISCO DE CONCHOS
# Sustituido en MUNICIPIO_RES
# 59
# con DESCRIPCIÓN SAN FRANCISCO DEL ORO
# Sustituido en MUNICIPIO_RES
# 60
# con DESCRIPCIÓN SANTA BÁRBARA
# Sustituido en MUNICIPIO_RES
# 61
# con DESCRIPCIÓN SATEVÓ
# Sustituido en MUNICIPIO_RES
# 62
# con DESCRIPCIÓN SAUCILLO
# Sustituido en MUNICIPIO_RES
# 63
# con DESCRIPCIÓN TEMÓSACHIC
# Sustituido en MUNICIPIO_RES
# 64
# con DESCRIPCIÓN EL TULE
# Sustituido en MUNICIPIO_RES
# 65
# con DESCRIPCIÓN URIQUE
# Sustituido en MUNICIPIO_RES
# 66
# con DESCRIPCIÓN URUACHI
# Sustituido en MUNICIPIO_RES
# 67
# con DESCRIPCIÓN VALLE DE ZARAGOZA
# Sustituido en MUNICIPIO_RES
# 999
# con DESCRIPCIÓN NO ESPECIFICADO
# Sustituido en MUNICIPIO_RES
# 2
# con DESCRIPCIÓN AZCAPOTZALCO
# Sustituido en MUNICIPIO_RES
# 3
# con DESCRIPCIÓN COYOACÁN
# Sustituido en MUNICIPIO_RES
# 4
# con DESCRIPCIÓN CUAJIMALPA DE MORELOS
# Sustituido en MUNICIPIO_RES
# 5
# con DESCRIPCIÓN GUSTAVO A. MADERO
# Sustituido en MUNICIPIO_RES
# 6
# con DESCRIPCIÓN IZTACALCO
# Sustituido en MUNICIPIO_RES
# 7
# con DESCRIPCIÓN IZTAPALAPA
# Sustituido en MUNICIPIO_RES
# 8
# con DESCRIPCIÓN LA MAGDALENA CONTRERAS
# Sustituido en MUNICIPIO_RES
# 9
# con DESCRIPCIÓN MILPA ALTA
# Sustituido en MUNICIPIO_RES
# 10
# con DESCRIPCIÓN ÁLVARO OBREGÓN
# Sustituido en MUNICIPIO_RES
# 11
# con DESCRIPCIÓN TLÁHUAC
# Sustituido en MUNICIPIO_RES
# 12
# con DESCRIPCIÓN TLALPAN
# Sustituido en MUNICIPIO_RES
# 13
# con DESCRIPCIÓN XOCHIMILCO
# Sustituido en MUNICIPIO_RES
# 14
# con DESCRIPCIÓN BENITO JUÁREZ
# Sustituido en MUNICIPIO_RES
# 15
# con DESCRIPCIÓN CUAUHTÉMOC
# Sustituido en MUNICIPIO_RES
# 16
# con DESCRIPCIÓN MIGUEL HIDALGO
# Sustituido en MUNICIPIO_RES
# 17
# con DESCRIPCIÓN VENUSTIANO CARRANZA
# Sustituido en MUNICIPIO_RES
# 999
# con DESCRIPCIÓN NO ESPECIFICADO
# Sustituido en MUNICIPIO_RES
# 1
# con DESCRIPCIÓN CANATLÁN
# Sustituido en MUNICIPIO_RES
# 2
# con DESCRIPCIÓN CANELAS
# Sustituido en MUNICIPIO_RES
# 3
# con DESCRIPCIÓN CONETO DE COMONFORT
# Sustituido en MUNICIPIO_RES
# 4
# con DESCRIPCIÓN CUENCAMÉ
# Sustituido en MUNICIPIO_RES
# 5
# con DESCRIPCIÓN DURANGO
# Sustituido en MUNICIPIO_RES
# 6
# con DESCRIPCIÓN GENERAL SIMÓN BOLÍVAR
# Sustituido en MUNICIPIO_RES
# 7
# con DESCRIPCIÓN GÓMEZ PALACIO
# Sustituido en MUNICIPIO_RES
# 8
# con DESCRIPCIÓN GUADALUPE VICTORIA
# Sustituido en MUNICIPIO_RES
# 9
# con DESCRIPCIÓN GUANACEVÍ
# Sustituido en MUNICIPIO_RES
# 10
# con DESCRIPCIÓN HIDALGO
# Sustituido en MUNICIPIO_RES
# 11
# con DESCRIPCIÓN INDÉ
# Sustituido en MUNICIPIO_RES
# 12
# con DESCRIPCIÓN LERDO
# Sustituido en MUNICIPIO_RES
# 13
# con DESCRIPCIÓN MAPIMÍ
# Sustituido en MUNICIPIO_RES
# 14
# con DESCRIPCIÓN MEZQUITAL
# Sustituido en MUNICIPIO_RES
# 15
# con DESCRIPCIÓN NAZAS
# Sustituido en MUNICIPIO_RES
# 16
# con DESCRIPCIÓN NOMBRE DE DIOS
# Sustituido en MUNICIPIO_RES
# 17
# con DESCRIPCIÓN OCAMPO
# Sustituido en MUNICIPIO_RES
# 18
# con DESCRIPCIÓN EL ORO
# Sustituido en MUNICIPIO_RES
# 19
# con DESCRIPCIÓN OTÁEZ
# Sustituido en MUNICIPIO_RES
# 20
# con DESCRIPCIÓN PÁNUCO DE CORONADO
# Sustituido en MUNICIPIO_RES
# 21
# con DESCRIPCIÓN PEÑÓN BLANCO
# Sustituido en MUNICIPIO_RES
# 22
# con DESCRIPCIÓN POANAS
# Sustituido en MUNICIPIO_RES
# 23
# con DESCRIPCIÓN PUEBLO NUEVO
# Sustituido en MUNICIPIO_RES
# 24
# con DESCRIPCIÓN RODEO
# Sustituido en MUNICIPIO_RES
# 25
# con DESCRIPCIÓN SAN BERNARDO
# Sustituido en MUNICIPIO_RES
# 26
# con DESCRIPCIÓN SAN DIMAS
# Sustituido en MUNICIPIO_RES
# 27
# con DESCRIPCIÓN SAN JUAN DE GUADALUPE
# Sustituido en MUNICIPIO_RES
# 28
# con DESCRIPCIÓN SAN JUAN DEL RÍO
# Sustituido en MUNICIPIO_RES
# 29
# con DESCRIPCIÓN SAN LUIS DEL CORDERO
# Sustituido en MUNICIPIO_RES
# 30
# con DESCRIPCIÓN SAN PEDRO DEL GALLO
# Sustituido en MUNICIPIO_RES
# 31
# con DESCRIPCIÓN SANTA CLARA
# Sustituido en MUNICIPIO_RES
# 32
# con DESCRIPCIÓN SANTIAGO PAPASQUIARO
# Sustituido en MUNICIPIO_RES
# 33
# con DESCRIPCIÓN SÚCHIL
# Sustituido en MUNICIPIO_RES
# 34
# con DESCRIPCIÓN TAMAZULA
# Sustituido en MUNICIPIO_RES
# 35
# con DESCRIPCIÓN TEPEHUANES
# Sustituido en MUNICIPIO_RES
# 36
# con DESCRIPCIÓN TLAHUALILO
# Sustituido en MUNICIPIO_RES
# 37
# con DESCRIPCIÓN TOPIA
# Sustituido en MUNICIPIO_RES
# 38
# con DESCRIPCIÓN VICENTE GUERRERO
# Sustituido en MUNICIPIO_RES
# 39
# con DESCRIPCIÓN NUEVO IDEAL
# Sustituido en MUNICIPIO_RES
# 999
# con DESCRIPCIÓN NO ESPECIFICADO
# Sustituido en MUNICIPIO_RES
# 1
# con DESCRIPCIÓN ABASOLO
# Sustituido en MUNICIPIO_RES
# 2
# con DESCRIPCIÓN ACÁMBARO
# Sustituido en MUNICIPIO_RES
# 3
# con DESCRIPCIÓN SAN MIGUEL DE ALLENDE
# Sustituido en MUNICIPIO_RES
# 4
# con DESCRIPCIÓN APASEO EL ALTO
# Sustituido en MUNICIPIO_RES
# 5
# con DESCRIPCIÓN APASEO EL GRANDE
# Sustituido en MUNICIPIO_RES
# 6
# con DESCRIPCIÓN ATARJEA
# Sustituido en MUNICIPIO_RES
# 7
# con DESCRIPCIÓN CELAYA
# Sustituido en MUNICIPIO_RES
# 8
# con DESCRIPCIÓN MANUEL DOBLADO
# Sustituido en MUNICIPIO_RES
# 9
# con DESCRIPCIÓN COMONFORT
# Sustituido en MUNICIPIO_RES
# 10
# con DESCRIPCIÓN CORONEO
# Sustituido en MUNICIPIO_RES
# 11
# con DESCRIPCIÓN CORTAZAR
# Sustituido en MUNICIPIO_RES
# 12
# con DESCRIPCIÓN CUERÁMARO
# Sustituido en MUNICIPIO_RES
# 13
# con DESCRIPCIÓN DOCTOR MORA
# Sustituido en MUNICIPIO_RES
# 14
# con DESCRIPCIÓN DOLORES HIDALGO CUNA DE LA INDEPENDENCIA NACIONAL
# Sustituido en MUNICIPIO_RES
# 15
# con DESCRIPCIÓN GUANAJUATO
# Sustituido en MUNICIPIO_RES
# 16
# con DESCRIPCIÓN HUANÍMARO
# Sustituido en MUNICIPIO_RES
# 17
# con DESCRIPCIÓN IRAPUATO
# Sustituido en MUNICIPIO_RES
# 18
# con DESCRIPCIÓN JARAL DEL PROGRESO
# Sustituido en MUNICIPIO_RES
# 19
# con DESCRIPCIÓN JERÉCUARO
# Sustituido en MUNICIPIO_RES
# 20
# con DESCRIPCIÓN LEÓN
# Sustituido en MUNICIPIO_RES
# 21
# con DESCRIPCIÓN MOROLEÓN
# Sustituido en MUNICIPIO_RES
# 22
# con DESCRIPCIÓN OCAMPO
# Sustituido en MUNICIPIO_RES
# 23
# con DESCRIPCIÓN PÉNJAMO
# Sustituido en MUNICIPIO_RES
# 24
# con DESCRIPCIÓN PUEBLO NUEVO
# Sustituido en MUNICIPIO_RES
# 25
# con DESCRIPCIÓN PURÍSIMA DEL RINCÓN
# Sustituido en MUNICIPIO_RES
# 26
# con DESCRIPCIÓN ROMITA
# Sustituido en MUNICIPIO_RES
# 27
# con DESCRIPCIÓN SALAMANCA
# Sustituido en MUNICIPIO_RES
# 28
# con DESCRIPCIÓN SALVATIERRA
# Sustituido en MUNICIPIO_RES
# 29
# con DESCRIPCIÓN SAN DIEGO DE LA UNIÓN
# Sustituido en MUNICIPIO_RES
# 30
# con DESCRIPCIÓN SAN FELIPE
# Sustituido en MUNICIPIO_RES
# 31
# con DESCRIPCIÓN SAN FRANCISCO DEL RINCÓN
# Sustituido en MUNICIPIO_RES
# 32
# con DESCRIPCIÓN SAN JOSÉ ITURBIDE
# Sustituido en MUNICIPIO_RES
# 33
# con DESCRIPCIÓN SAN LUIS DE LA PAZ
# Sustituido en MUNICIPIO_RES
# 34
# con DESCRIPCIÓN SANTA CATARINA
# Sustituido en MUNICIPIO_RES
# 35
# con DESCRIPCIÓN SANTA CRUZ DE JUVENTINO ROSAS
# Sustituido en MUNICIPIO_RES
# 36
# con DESCRIPCIÓN SANTIAGO MARAVATÍO
# Sustituido en MUNICIPIO_RES
# 37
# con DESCRIPCIÓN SILAO DE LA VICTORIA
# Sustituido en MUNICIPIO_RES
# 38
# con DESCRIPCIÓN TARANDACUAO
# Sustituido en MUNICIPIO_RES
# 39
# con DESCRIPCIÓN TARIMORO
# Sustituido en MUNICIPIO_RES
# 40
# con DESCRIPCIÓN TIERRA BLANCA
# Sustituido en MUNICIPIO_RES
# 41
# con DESCRIPCIÓN URIANGATO
# Sustituido en MUNICIPIO_RES
# 42
# con DESCRIPCIÓN VALLE DE SANTIAGO
# Sustituido en MUNICIPIO_RES
# 43
# con DESCRIPCIÓN VICTORIA
# Sustituido en MUNICIPIO_RES
# 44
# con DESCRIPCIÓN VILLAGRÁN
# Sustituido en MUNICIPIO_RES
# 45
# con DESCRIPCIÓN XICHÚ
# Sustituido en MUNICIPIO_RES
# 46
# con DESCRIPCIÓN YURIRIA
# Sustituido en MUNICIPIO_RES
# 999
# con DESCRIPCIÓN NO ESPECIFICADO
# Sustituido en MUNICIPIO_RES
# 1
# con DESCRIPCIÓN ACAPULCO DE JUÁREZ
# Sustituido en MUNICIPIO_RES
# 2
# con DESCRIPCIÓN AHUACUOTZINGO
# Sustituido en MUNICIPIO_RES
# 3
# con DESCRIPCIÓN AJUCHITLÁN DEL PROGRESO
# Sustituido en MUNICIPIO_RES
# 4
# con DESCRIPCIÓN ALCOZAUCA DE GUERRERO
# Sustituido en MUNICIPIO_RES
# 5
# con DESCRIPCIÓN ALPOYECA
# Sustituido en MUNICIPIO_RES
# 6
# con DESCRIPCIÓN APAXTLA
# Sustituido en MUNICIPIO_RES
# 7
# con DESCRIPCIÓN ARCELIA
# Sustituido en MUNICIPIO_RES
# 8
# con DESCRIPCIÓN ATENANGO DEL RÍO
# Sustituido en MUNICIPIO_RES
# 9
# con DESCRIPCIÓN ATLAMAJALCINGO DEL MONTE
# Sustituido en MUNICIPIO_RES
# 10
# con DESCRIPCIÓN ATLIXTAC
# Sustituido en MUNICIPIO_RES
# 11
# con DESCRIPCIÓN ATOYAC DE ÁLVAREZ
# Sustituido en MUNICIPIO_RES
# 12
# con DESCRIPCIÓN AYUTLA DE LOS LIBRES
# Sustituido en MUNICIPIO_RES
# 13
# con DESCRIPCIÓN AZOYÚ
# Sustituido en MUNICIPIO_RES
# 14
# con DESCRIPCIÓN BENITO JUÁREZ
# Sustituido en MUNICIPIO_RES
# 15
# con DESCRIPCIÓN BUENAVISTA DE CUÉLLAR
# Sustituido en MUNICIPIO_RES
# 16
# con DESCRIPCIÓN COAHUAYUTLA DE JOSÉ MARÍA IZAZAGA
# Sustituido en MUNICIPIO_RES
# 17
# con DESCRIPCIÓN COCULA
# Sustituido en MUNICIPIO_RES
# 18
# con DESCRIPCIÓN COPALA
# Sustituido en MUNICIPIO_RES
# 19
# con DESCRIPCIÓN COPALILLO
# Sustituido en MUNICIPIO_RES
# 20
# con DESCRIPCIÓN COPANATOYAC
# Sustituido en MUNICIPIO_RES
# 21
# con DESCRIPCIÓN COYUCA DE BENÍTEZ
# Sustituido en MUNICIPIO_RES
# 22
# con DESCRIPCIÓN COYUCA DE CATALÁN
# Sustituido en MUNICIPIO_RES
# 23
# con DESCRIPCIÓN CUAJINICUILAPA
# Sustituido en MUNICIPIO_RES
# 24
# con DESCRIPCIÓN CUALÁC
# Sustituido en MUNICIPIO_RES
# 25
# con DESCRIPCIÓN CUAUTEPEC
# Sustituido en MUNICIPIO_RES
# 26
# con DESCRIPCIÓN CUETZALA DEL PROGRESO
# Sustituido en MUNICIPIO_RES
# 27
# con DESCRIPCIÓN CUTZAMALA DE PINZÓN
# Sustituido en MUNICIPIO_RES
# 28
# con DESCRIPCIÓN CHILAPA DE ÁLVAREZ
# Sustituido en MUNICIPIO_RES
# 29
# con DESCRIPCIÓN CHILPANCINGO DE LOS BRAVO
# Sustituido en MUNICIPIO_RES
# 30
# con DESCRIPCIÓN FLORENCIO VILLARREAL
# Sustituido en MUNICIPIO_RES
# 31
# con DESCRIPCIÓN GENERAL CANUTO A. NERI
# Sustituido en MUNICIPIO_RES
# 32
# con DESCRIPCIÓN GENERAL HELIODORO CASTILLO
# Sustituido en MUNICIPIO_RES
# 33
# con DESCRIPCIÓN HUAMUXTITLÁN
# Sustituido en MUNICIPIO_RES
# 34
# con DESCRIPCIÓN HUITZUCO DE LOS FIGUEROA
# Sustituido en MUNICIPIO_RES
# 35
# con DESCRIPCIÓN IGUALA DE LA INDEPENDENCIA
# Sustituido en MUNICIPIO_RES
# 36
# con DESCRIPCIÓN IGUALAPA
# Sustituido en MUNICIPIO_RES
# 37
# con DESCRIPCIÓN IXCATEOPAN DE CUAUHTÉMOC
# Sustituido en MUNICIPIO_RES
# 38
# con DESCRIPCIÓN ZIHUATANEJO DE AZUETA
# Sustituido en MUNICIPIO_RES
# 39
# con DESCRIPCIÓN JUAN R. ESCUDERO
# Sustituido en MUNICIPIO_RES
# 40
# con DESCRIPCIÓN LEONARDO BRAVO
# Sustituido en MUNICIPIO_RES
# 41
# con DESCRIPCIÓN MALINALTEPEC
# Sustituido en MUNICIPIO_RES
# 42
# con DESCRIPCIÓN MÁRTIR DE CUILAPAN
# Sustituido en MUNICIPIO_RES
# 43
# con DESCRIPCIÓN METLATÓNOC
# Sustituido en MUNICIPIO_RES
# 44
# con DESCRIPCIÓN MOCHITLÁN
# Sustituido en MUNICIPIO_RES
# 45
# con DESCRIPCIÓN OLINALÁ
# Sustituido en MUNICIPIO_RES
# 46
# con DESCRIPCIÓN OMETEPEC
# Sustituido en MUNICIPIO_RES
# 47
# con DESCRIPCIÓN PEDRO ASCENCIO ALQUISIRAS
# Sustituido en MUNICIPIO_RES
# 48
# con DESCRIPCIÓN PETATLÁN
# Sustituido en MUNICIPIO_RES
# 49
# con DESCRIPCIÓN PILCAYA
# Sustituido en MUNICIPIO_RES
# 50
# con DESCRIPCIÓN PUNGARABATO
# Sustituido en MUNICIPIO_RES
# 51
# con DESCRIPCIÓN QUECHULTENANGO
# Sustituido en MUNICIPIO_RES
# 52
# con DESCRIPCIÓN SAN LUIS ACATLÁN
# Sustituido en MUNICIPIO_RES
# 53
# con DESCRIPCIÓN SAN MARCOS
# Sustituido en MUNICIPIO_RES
# 54
# con DESCRIPCIÓN SAN MIGUEL TOTOLAPAN
# Sustituido en MUNICIPIO_RES
# 55
# con DESCRIPCIÓN TAXCO DE ALARCÓN
# Sustituido en MUNICIPIO_RES
# 56
# con DESCRIPCIÓN TECOANAPA
# Sustituido en MUNICIPIO_RES
# 57
# con DESCRIPCIÓN TÉCPAN DE GALEANA
# Sustituido en MUNICIPIO_RES
# 58
# con DESCRIPCIÓN TELOLOAPAN
# Sustituido en MUNICIPIO_RES
# 59
# con DESCRIPCIÓN TEPECOACUILCO DE TRUJANO
# Sustituido en MUNICIPIO_RES
# 60
# con DESCRIPCIÓN TETIPAC
# Sustituido en MUNICIPIO_RES
# 61
# con DESCRIPCIÓN TIXTLA DE GUERRERO
# Sustituido en MUNICIPIO_RES
# 62
# con DESCRIPCIÓN TLACOACHISTLAHUACA
# Sustituido en MUNICIPIO_RES
# 63
# con DESCRIPCIÓN TLACOAPA
# Sustituido en MUNICIPIO_RES
# 64
# con DESCRIPCIÓN TLALCHAPA
# Sustituido en MUNICIPIO_RES
# 65
# con DESCRIPCIÓN TLALIXTAQUILLA DE MALDONADO
# Sustituido en MUNICIPIO_RES
# 66
# con DESCRIPCIÓN TLAPA DE COMONFORT
# Sustituido en MUNICIPIO_RES
# 67
# con DESCRIPCIÓN TLAPEHUALA
# Sustituido en MUNICIPIO_RES
# 68
# con DESCRIPCIÓN LA UNIÓN DE ISIDORO MONTES DE OCA
# Sustituido en MUNICIPIO_RES
# 69
# con DESCRIPCIÓN XALPATLÁHUAC
# Sustituido en MUNICIPIO_RES
# 70
# con DESCRIPCIÓN XOCHIHUEHUETLÁN
# Sustituido en MUNICIPIO_RES
# 71
# con DESCRIPCIÓN XOCHISTLAHUACA
# Sustituido en MUNICIPIO_RES
# 72
# con DESCRIPCIÓN ZAPOTITLÁN TABLAS
# Sustituido en MUNICIPIO_RES
# 73
# con DESCRIPCIÓN ZIRÁNDARO
# Sustituido en MUNICIPIO_RES
# 74
# con DESCRIPCIÓN ZITLALA
# Sustituido en MUNICIPIO_RES
# 75
# con DESCRIPCIÓN EDUARDO NERI
# Sustituido en MUNICIPIO_RES
# 76
# con DESCRIPCIÓN ACATEPEC
# Sustituido en MUNICIPIO_RES
# 77
# con DESCRIPCIÓN MARQUELIA
# Sustituido en MUNICIPIO_RES
# 78
# con DESCRIPCIÓN COCHOAPA EL GRANDE
# Sustituido en MUNICIPIO_RES
# 79
# con DESCRIPCIÓN JOSÉ JOAQUÍN DE HERRERA
# Sustituido en MUNICIPIO_RES
# 80
# con DESCRIPCIÓN JUCHITÁN
# Sustituido en MUNICIPIO_RES
# 81
# con DESCRIPCIÓN ILIATENCO
# Sustituido en MUNICIPIO_RES
# 999
# con DESCRIPCIÓN NO ESPECIFICADO
# Sustituido en MUNICIPIO_RES
# 1
# con DESCRIPCIÓN ACATLÁN
# Sustituido en MUNICIPIO_RES
# 2
# con DESCRIPCIÓN ACAXOCHITLÁN
# Sustituido en MUNICIPIO_RES
# 3
# con DESCRIPCIÓN ACTOPAN
# Sustituido en MUNICIPIO_RES
# 4
# con DESCRIPCIÓN AGUA BLANCA DE ITURBIDE
# Sustituido en MUNICIPIO_RES
# 5
# con DESCRIPCIÓN AJACUBA
# Sustituido en MUNICIPIO_RES
# 6
# con DESCRIPCIÓN ALFAJAYUCAN
# Sustituido en MUNICIPIO_RES
# 7
# con DESCRIPCIÓN ALMOLOYA
# Sustituido en MUNICIPIO_RES
# 8
# con DESCRIPCIÓN APAN
# Sustituido en MUNICIPIO_RES
# 9
# con DESCRIPCIÓN EL ARENAL
# Sustituido en MUNICIPIO_RES
# 10
# con DESCRIPCIÓN ATITALAQUIA
# Sustituido en MUNICIPIO_RES
# 11
# con DESCRIPCIÓN ATLAPEXCO
# Sustituido en MUNICIPIO_RES
# 12
# con DESCRIPCIÓN ATOTONILCO EL GRANDE
# Sustituido en MUNICIPIO_RES
# 13
# con DESCRIPCIÓN ATOTONILCO DE TULA
# Sustituido en MUNICIPIO_RES
# 14
# con DESCRIPCIÓN CALNALI
# Sustituido en MUNICIPIO_RES
# 15
# con DESCRIPCIÓN CARDONAL
# Sustituido en MUNICIPIO_RES
# 16
# con DESCRIPCIÓN CUAUTEPEC DE HINOJOSA
# Sustituido en MUNICIPIO_RES
# 17
# con DESCRIPCIÓN CHAPANTONGO
# Sustituido en MUNICIPIO_RES
# 18
# con DESCRIPCIÓN CHAPULHUACÁN
# Sustituido en MUNICIPIO_RES
# 19
# con DESCRIPCIÓN CHILCUAUTLA
# Sustituido en MUNICIPIO_RES
# 20
# con DESCRIPCIÓN ELOXOCHITLÁN
# Sustituido en MUNICIPIO_RES
# 21
# con DESCRIPCIÓN EMILIANO ZAPATA
# Sustituido en MUNICIPIO_RES
# 22
# con DESCRIPCIÓN EPAZOYUCAN
# Sustituido en MUNICIPIO_RES
# 23
# con DESCRIPCIÓN FRANCISCO I. MADERO
# Sustituido en MUNICIPIO_RES
# 24
# con DESCRIPCIÓN HUASCA DE OCAMPO
# Sustituido en MUNICIPIO_RES
# 25
# con DESCRIPCIÓN HUAUTLA
# Sustituido en MUNICIPIO_RES
# 26
# con DESCRIPCIÓN HUAZALINGO
# Sustituido en MUNICIPIO_RES
# 27
# con DESCRIPCIÓN HUEHUETLA
# Sustituido en MUNICIPIO_RES
# 28
# con DESCRIPCIÓN HUEJUTLA DE REYES
# Sustituido en MUNICIPIO_RES
# 29
# con DESCRIPCIÓN HUICHAPAN
# Sustituido en MUNICIPIO_RES
# 30
# con DESCRIPCIÓN IXMIQUILPAN
# Sustituido en MUNICIPIO_RES
# 31
# con DESCRIPCIÓN JACALA DE LEDEZMA
# Sustituido en MUNICIPIO_RES
# 32
# con DESCRIPCIÓN JALTOCÁN
# Sustituido en MUNICIPIO_RES
# 33
# con DESCRIPCIÓN JUÁREZ HIDALGO
# Sustituido en MUNICIPIO_RES
# 34
# con DESCRIPCIÓN LOLOTLA
# Sustituido en MUNICIPIO_RES
# 35
# con DESCRIPCIÓN METEPEC
# Sustituido en MUNICIPIO_RES
# 36
# con DESCRIPCIÓN SAN AGUSTÍN METZQUITITLÁN
# Sustituido en MUNICIPIO_RES
# 37
# con DESCRIPCIÓN METZTITLÁN
# Sustituido en MUNICIPIO_RES
# 38
# con DESCRIPCIÓN MINERAL DEL CHICO
# Sustituido en MUNICIPIO_RES
# 39
# con DESCRIPCIÓN MINERAL DEL MONTE
# Sustituido en MUNICIPIO_RES
# 40
# con DESCRIPCIÓN LA MISIÓN
# Sustituido en MUNICIPIO_RES
# 41
# con DESCRIPCIÓN MIXQUIAHUALA DE JUÁREZ
# Sustituido en MUNICIPIO_RES
# 42
# con DESCRIPCIÓN MOLANGO DE ESCAMILLA
# Sustituido en MUNICIPIO_RES
# 43
# con DESCRIPCIÓN NICOLÁS FLORES
# Sustituido en MUNICIPIO_RES
# 44
# con DESCRIPCIÓN NOPALA DE VILLAGRÁN
# Sustituido en MUNICIPIO_RES
# 45
# con DESCRIPCIÓN OMITLÁN DE JUÁREZ
# Sustituido en MUNICIPIO_RES
# 46
# con DESCRIPCIÓN SAN FELIPE ORIZATLÁN
# Sustituido en MUNICIPIO_RES
# 47
# con DESCRIPCIÓN PACULA
# Sustituido en MUNICIPIO_RES
# 48
# con DESCRIPCIÓN PACHUCA DE SOTO
# Sustituido en MUNICIPIO_RES
# 49
# con DESCRIPCIÓN PISAFLORES
# Sustituido en MUNICIPIO_RES
# 50
# con DESCRIPCIÓN PROGRESO DE OBREGÓN
# Sustituido en MUNICIPIO_RES
# 51
# con DESCRIPCIÓN MINERAL DE LA REFORMA
# Sustituido en MUNICIPIO_RES
# 52
# con DESCRIPCIÓN SAN AGUSTÍN TLAXIACA
# Sustituido en MUNICIPIO_RES
# 53
# con DESCRIPCIÓN SAN BARTOLO TUTOTEPEC
# Sustituido en MUNICIPIO_RES
# 54
# con DESCRIPCIÓN SAN SALVADOR
# Sustituido en MUNICIPIO_RES
# 55
# con DESCRIPCIÓN SANTIAGO DE ANAYA
# Sustituido en MUNICIPIO_RES
# 56
# con DESCRIPCIÓN SANTIAGO TULANTEPEC DE LUGO GUERRERO
# Sustituido en MUNICIPIO_RES
# 57
# con DESCRIPCIÓN SINGUILUCAN
# Sustituido en MUNICIPIO_RES
# 58
# con DESCRIPCIÓN TASQUILLO
# Sustituido en MUNICIPIO_RES
# 59
# con DESCRIPCIÓN TECOZAUTLA
# Sustituido en MUNICIPIO_RES
# 60
# con DESCRIPCIÓN TENANGO DE DORIA
# Sustituido en MUNICIPIO_RES
# 61
# con DESCRIPCIÓN TEPEAPULCO
# Sustituido en MUNICIPIO_RES
# 62
# con DESCRIPCIÓN TEPEHUACÁN DE GUERRERO
# Sustituido en MUNICIPIO_RES
# 63
# con DESCRIPCIÓN TEPEJI DEL RÍO DE OCAMPO
# Sustituido en MUNICIPIO_RES
# 64
# con DESCRIPCIÓN TEPETITLÁN
# Sustituido en MUNICIPIO_RES
# 65
# con DESCRIPCIÓN TETEPANGO
# Sustituido en MUNICIPIO_RES
# 66
# con DESCRIPCIÓN VILLA DE TEZONTEPEC
# Sustituido en MUNICIPIO_RES
# 67
# con DESCRIPCIÓN TEZONTEPEC DE ALDAMA
# Sustituido en MUNICIPIO_RES
# 68
# con DESCRIPCIÓN TIANGUISTENGO
# Sustituido en MUNICIPIO_RES
# 69
# con DESCRIPCIÓN TIZAYUCA
# Sustituido en MUNICIPIO_RES
# 70
# con DESCRIPCIÓN TLAHUELILPAN
# Sustituido en MUNICIPIO_RES
# 71
# con DESCRIPCIÓN TLAHUILTEPA
# Sustituido en MUNICIPIO_RES
# 72
# con DESCRIPCIÓN TLANALAPA
# Sustituido en MUNICIPIO_RES
# 73
# con DESCRIPCIÓN TLANCHINOL
# Sustituido en MUNICIPIO_RES
# 74
# con DESCRIPCIÓN TLAXCOAPAN
# Sustituido en MUNICIPIO_RES
# 75
# con DESCRIPCIÓN TOLCAYUCA
# Sustituido en MUNICIPIO_RES
# 76
# con DESCRIPCIÓN TULA DE ALLENDE
# Sustituido en MUNICIPIO_RES
# 77
# con DESCRIPCIÓN TULANCINGO DE BRAVO
# Sustituido en MUNICIPIO_RES
# 78
# con DESCRIPCIÓN XOCHIATIPAN
# Sustituido en MUNICIPIO_RES
# 79
# con DESCRIPCIÓN XOCHICOATLÁN
# Sustituido en MUNICIPIO_RES
# 80
# con DESCRIPCIÓN YAHUALICA
# Sustituido en MUNICIPIO_RES
# 81
# con DESCRIPCIÓN ZACUALTIPÁN DE ÁNGELES
# Sustituido en MUNICIPIO_RES
# 82
# con DESCRIPCIÓN ZAPOTLÁN DE JUÁREZ
# Sustituido en MUNICIPIO_RES
# 83
# con DESCRIPCIÓN ZEMPOALA
# Sustituido en MUNICIPIO_RES
# 84
# con DESCRIPCIÓN ZIMAPÁN
# Sustituido en MUNICIPIO_RES
# 999
# con DESCRIPCIÓN NO ESPECIFICADO
# Sustituido en MUNICIPIO_RES
# 1
# con DESCRIPCIÓN ACATIC
# Sustituido en MUNICIPIO_RES
# 2
# con DESCRIPCIÓN ACATLÁN DE JUÁREZ
# Sustituido en MUNICIPIO_RES
# 3
# con DESCRIPCIÓN AHUALULCO DE MERCADO
# Sustituido en MUNICIPIO_RES
# 4
# con DESCRIPCIÓN AMACUECA
# Sustituido en MUNICIPIO_RES
# 5
# con DESCRIPCIÓN AMATITÁN
# Sustituido en MUNICIPIO_RES
# 6
# con DESCRIPCIÓN AMECA
# Sustituido en MUNICIPIO_RES
# 7
# con DESCRIPCIÓN SAN JUANITO DE ESCOBEDO
# Sustituido en MUNICIPIO_RES
# 8
# con DESCRIPCIÓN ARANDAS
# Sustituido en MUNICIPIO_RES
# 9
# con DESCRIPCIÓN EL ARENAL
# Sustituido en MUNICIPIO_RES
# 10
# con DESCRIPCIÓN ATEMAJAC DE BRIZUELA
# Sustituido en MUNICIPIO_RES
# 11
# con DESCRIPCIÓN ATENGO
# Sustituido en MUNICIPIO_RES
# 12
# con DESCRIPCIÓN ATENGUILLO
# Sustituido en MUNICIPIO_RES
# 13
# con DESCRIPCIÓN ATOTONILCO EL ALTO
# Sustituido en MUNICIPIO_RES
# 14
# con DESCRIPCIÓN ATOYAC
# Sustituido en MUNICIPIO_RES
# 15
# con DESCRIPCIÓN AUTLÁN DE NAVARRO
# Sustituido en MUNICIPIO_RES
# 16
# con DESCRIPCIÓN AYOTLÁN
# Sustituido en MUNICIPIO_RES
# 17
# con DESCRIPCIÓN AYUTLA
# Sustituido en MUNICIPIO_RES
# 18
# con DESCRIPCIÓN LA BARCA
# Sustituido en MUNICIPIO_RES
# 19
# con DESCRIPCIÓN BOLAÑOS
# Sustituido en MUNICIPIO_RES
# 20
# con DESCRIPCIÓN CABO CORRIENTES
# Sustituido en MUNICIPIO_RES
# 21
# con DESCRIPCIÓN CASIMIRO CASTILLO
# Sustituido en MUNICIPIO_RES
# 22
# con DESCRIPCIÓN CIHUATLÁN
# Sustituido en MUNICIPIO_RES
# 23
# con DESCRIPCIÓN ZAPOTLÁN EL GRANDE
# Sustituido en MUNICIPIO_RES
# 24
# con DESCRIPCIÓN COCULA
# Sustituido en MUNICIPIO_RES
# 25
# con DESCRIPCIÓN COLOTLÁN
# Sustituido en MUNICIPIO_RES
# 26
# con DESCRIPCIÓN CONCEPCIÓN DE BUENOS AIRES
# Sustituido en MUNICIPIO_RES
# 27
# con DESCRIPCIÓN CUAUTITLÁN DE GARCÍA BARRAGÁN
# Sustituido en MUNICIPIO_RES
# 28
# con DESCRIPCIÓN CUAUTLA
# Sustituido en MUNICIPIO_RES
# 29
# con DESCRIPCIÓN CUQUÍO
# Sustituido en MUNICIPIO_RES
# 30
# con DESCRIPCIÓN CHAPALA
# Sustituido en MUNICIPIO_RES
# 31
# con DESCRIPCIÓN CHIMALTITÁN
# Sustituido en MUNICIPIO_RES
# 32
# con DESCRIPCIÓN CHIQUILISTLÁN
# Sustituido en MUNICIPIO_RES
# 33
# con DESCRIPCIÓN DEGOLLADO
# Sustituido en MUNICIPIO_RES
# 34
# con DESCRIPCIÓN EJUTLA
# Sustituido en MUNICIPIO_RES
# 35
# con DESCRIPCIÓN ENCARNACIÓN DE DÍAZ
# Sustituido en MUNICIPIO_RES
# 36
# con DESCRIPCIÓN ETZATLÁN
# Sustituido en MUNICIPIO_RES
# 37
# con DESCRIPCIÓN EL GRULLO
# Sustituido en MUNICIPIO_RES
# 38
# con DESCRIPCIÓN GUACHINANGO
# Sustituido en MUNICIPIO_RES
# 39
# con DESCRIPCIÓN GUADALAJARA
# Sustituido en MUNICIPIO_RES
# 40
# con DESCRIPCIÓN HOSTOTIPAQUILLO
# Sustituido en MUNICIPIO_RES
# 41
# con DESCRIPCIÓN HUEJÚCAR
# Sustituido en MUNICIPIO_RES
# 42
# con DESCRIPCIÓN HUEJUQUILLA EL ALTO
# Sustituido en MUNICIPIO_RES
# 43
# con DESCRIPCIÓN LA HUERTA
# Sustituido en MUNICIPIO_RES
# 44
# con DESCRIPCIÓN IXTLAHUACÁN DE LOS MEMBRILLOS
# Sustituido en MUNICIPIO_RES
# 45
# con DESCRIPCIÓN IXTLAHUACÁN DEL RÍO
# Sustituido en MUNICIPIO_RES
# 46
# con DESCRIPCIÓN JALOSTOTITLÁN
# Sustituido en MUNICIPIO_RES
# 47
# con DESCRIPCIÓN JAMAY
# Sustituido en MUNICIPIO_RES
# 48
# con DESCRIPCIÓN JESÚS MARÍA
# Sustituido en MUNICIPIO_RES
# 49
# con DESCRIPCIÓN JILOTLÁN DE LOS DOLORES
# Sustituido en MUNICIPIO_RES
# 50
# con DESCRIPCIÓN JOCOTEPEC
# Sustituido en MUNICIPIO_RES
# 51
# con DESCRIPCIÓN JUANACATLÁN
# Sustituido en MUNICIPIO_RES
# 52
# con DESCRIPCIÓN JUCHITLÁN
# Sustituido en MUNICIPIO_RES
# 53
# con DESCRIPCIÓN LAGOS DE MORENO
# Sustituido en MUNICIPIO_RES
# 54
# con DESCRIPCIÓN EL LIMÓN
# Sustituido en MUNICIPIO_RES
# 55
# con DESCRIPCIÓN MAGDALENA
# Sustituido en MUNICIPIO_RES
# 56
# con DESCRIPCIÓN SANTA MARÍA DEL ORO
# Sustituido en MUNICIPIO_RES
# 57
# con DESCRIPCIÓN LA MANZANILLA DE LA PAZ
# Sustituido en MUNICIPIO_RES
# 58
# con DESCRIPCIÓN MASCOTA
# Sustituido en MUNICIPIO_RES
# 59
# con DESCRIPCIÓN MAZAMITLA
# Sustituido en MUNICIPIO_RES
# 60
# con DESCRIPCIÓN MEXTICACÁN
# Sustituido en MUNICIPIO_RES
# 61
# con DESCRIPCIÓN MEZQUITIC
# Sustituido en MUNICIPIO_RES
# 62
# con DESCRIPCIÓN MIXTLÁN
# Sustituido en MUNICIPIO_RES
# 63
# con DESCRIPCIÓN OCOTLÁN
# Sustituido en MUNICIPIO_RES
# 64
# con DESCRIPCIÓN OJUELOS DE JALISCO
# Sustituido en MUNICIPIO_RES
# 65
# con DESCRIPCIÓN PIHUAMO
# Sustituido en MUNICIPIO_RES
# 66
# con DESCRIPCIÓN PONCITLÁN
# Sustituido en MUNICIPIO_RES
# 67
# con DESCRIPCIÓN PUERTO VALLARTA
# Sustituido en MUNICIPIO_RES
# 68
# con DESCRIPCIÓN VILLA PURIFICACIÓN
# Sustituido en MUNICIPIO_RES
# 69
# con DESCRIPCIÓN QUITUPAN
# Sustituido en MUNICIPIO_RES
# 70
# con DESCRIPCIÓN EL SALTO
# Sustituido en MUNICIPIO_RES
# 71
# con DESCRIPCIÓN SAN CRISTÓBAL DE LA BARRANCA
# Sustituido en MUNICIPIO_RES
# 72
# con DESCRIPCIÓN SAN DIEGO DE ALEJANDRÍA
# Sustituido en MUNICIPIO_RES
# 73
# con DESCRIPCIÓN SAN JUAN DE LOS LAGOS
# Sustituido en MUNICIPIO_RES
# 74
# con DESCRIPCIÓN SAN JULIÁN
# Sustituido en MUNICIPIO_RES
# 75
# con DESCRIPCIÓN SAN MARCOS
# Sustituido en MUNICIPIO_RES
# 76
# con DESCRIPCIÓN SAN MARTÍN DE BOLAÑOS
# Sustituido en MUNICIPIO_RES
# 77
# con DESCRIPCIÓN SAN MARTÍN HIDALGO
# Sustituido en MUNICIPIO_RES
# 78
# con DESCRIPCIÓN SAN MIGUEL EL ALTO
# Sustituido en MUNICIPIO_RES
# 79
# con DESCRIPCIÓN GÓMEZ FARÍAS
# Sustituido en MUNICIPIO_RES
# 80
# con DESCRIPCIÓN SAN SEBASTIÁN DEL OESTE
# Sustituido en MUNICIPIO_RES
# 81
# con DESCRIPCIÓN SANTA MARÍA DE LOS ÁNGELES
# Sustituido en MUNICIPIO_RES
# 82
# con DESCRIPCIÓN SAYULA
# Sustituido en MUNICIPIO_RES
# 83
# con DESCRIPCIÓN TALA
# Sustituido en MUNICIPIO_RES
# 84
# con DESCRIPCIÓN TALPA DE ALLENDE
# Sustituido en MUNICIPIO_RES
# 85
# con DESCRIPCIÓN TAMAZULA DE GORDIANO
# Sustituido en MUNICIPIO_RES
# 86
# con DESCRIPCIÓN TAPALPA
# Sustituido en MUNICIPIO_RES
# 87
# con DESCRIPCIÓN TECALITLÁN
# Sustituido en MUNICIPIO_RES
# 88
# con DESCRIPCIÓN TECOLOTLÁN
# Sustituido en MUNICIPIO_RES
# 89
# con DESCRIPCIÓN TECHALUTA DE MONTENEGRO
# Sustituido en MUNICIPIO_RES
# 90
# con DESCRIPCIÓN TENAMAXTLÁN
# Sustituido en MUNICIPIO_RES
# 91
# con DESCRIPCIÓN TEOCALTICHE
# Sustituido en MUNICIPIO_RES
# 92
# con DESCRIPCIÓN TEOCUITATLÁN DE CORONA
# Sustituido en MUNICIPIO_RES
# 93
# con DESCRIPCIÓN TEPATITLÁN DE MORELOS
# Sustituido en MUNICIPIO_RES
# 94
# con DESCRIPCIÓN TEQUILA
# Sustituido en MUNICIPIO_RES
# 95
# con DESCRIPCIÓN TEUCHITLÁN
# Sustituido en MUNICIPIO_RES
# 96
# con DESCRIPCIÓN TIZAPÁN EL ALTO
# Sustituido en MUNICIPIO_RES
# 97
# con DESCRIPCIÓN TLAJOMULCO DE ZÚÑIGA
# Sustituido en MUNICIPIO_RES
# 98
# con DESCRIPCIÓN SAN PEDRO TLAQUEPAQUE
# Sustituido en MUNICIPIO_RES
# 99
# con DESCRIPCIÓN TOLIMÁN
# Sustituido en MUNICIPIO_RES
# 100
# con DESCRIPCIÓN TOMATLÁN
# Sustituido en MUNICIPIO_RES
# 101
# con DESCRIPCIÓN TONALÁ
# Sustituido en MUNICIPIO_RES
# 102
# con DESCRIPCIÓN TONAYA
# Sustituido en MUNICIPIO_RES
# 103
# con DESCRIPCIÓN TONILA
# Sustituido en MUNICIPIO_RES
# 104
# con DESCRIPCIÓN TOTATICHE
# Sustituido en MUNICIPIO_RES
# 105
# con DESCRIPCIÓN TOTOTLÁN
# Sustituido en MUNICIPIO_RES
# 106
# con DESCRIPCIÓN TUXCACUESCO
# Sustituido en MUNICIPIO_RES
# 107
# con DESCRIPCIÓN TUXCUECA
# Sustituido en MUNICIPIO_RES
# 108
# con DESCRIPCIÓN TUXPAN
# Sustituido en MUNICIPIO_RES
# 109
# con DESCRIPCIÓN UNIÓN DE SAN ANTONIO
# Sustituido en MUNICIPIO_RES
# 110
# con DESCRIPCIÓN UNIÓN DE TULA
# Sustituido en MUNICIPIO_RES
# 111
# con DESCRIPCIÓN VALLE DE GUADALUPE
# Sustituido en MUNICIPIO_RES
# 112
# con DESCRIPCIÓN VALLE DE JUÁREZ
# Sustituido en MUNICIPIO_RES
# 113
# con DESCRIPCIÓN SAN GABRIEL
# Sustituido en MUNICIPIO_RES
# 114
# con DESCRIPCIÓN VILLA CORONA
# Sustituido en MUNICIPIO_RES
# 115
# con DESCRIPCIÓN VILLA GUERRERO
# Sustituido en MUNICIPIO_RES
# 116
# con DESCRIPCIÓN VILLA HIDALGO
# Sustituido en MUNICIPIO_RES
# 117
# con DESCRIPCIÓN CAÑADAS DE OBREGÓN
# Sustituido en MUNICIPIO_RES
# 118
# con DESCRIPCIÓN YAHUALICA DE GONZÁLEZ GALLO
# Sustituido en MUNICIPIO_RES
# 119
# con DESCRIPCIÓN ZACOALCO DE TORRES
# Sustituido en MUNICIPIO_RES
# 120
# con DESCRIPCIÓN ZAPOPAN
# Sustituido en MUNICIPIO_RES
# 121
# con DESCRIPCIÓN ZAPOTILTIC
# Sustituido en MUNICIPIO_RES
# ...
# Sustituido en MUNICIPIO_RES
# 34
# con DESCRIPCIÓN HUÉPAC
# Sustituido en MUNICIPIO_RES
# 35
# con DESCRIPCIÓN IMURIS
# Sustituido en MUNICIPIO_RES
# 36
# con DESCRIPCIÓN MAGDALENA
# Sustituido en MUNICIPIO_RES
# 37
# con DESCRIPCIÓN MAZATÁN
# Sustituido en MUNICIPIO_RES
# 38
# con DESCRIPCIÓN MOCTEZUMA
# Sustituido en MUNICIPIO_RES
# 39
# con DESCRIPCIÓN NACO
# Sustituido en MUNICIPIO_RES
# 40
# con DESCRIPCIÓN NÁCORI CHICO
# Sustituido en MUNICIPIO_RES
# 41
# con DESCRIPCIÓN NACOZARI DE GARCÍA
# Sustituido en MUNICIPIO_RES
# 42
# con DESCRIPCIÓN NAVOJOA
# Sustituido en MUNICIPIO_RES
# 43
# con DESCRIPCIÓN NOGALES
# Sustituido en MUNICIPIO_RES
# 44
# con DESCRIPCIÓN ONAVAS
# Sustituido en MUNICIPIO_RES
# 45
# con DESCRIPCIÓN OPODEPE
# Sustituido en MUNICIPIO_RES
# 46
# con DESCRIPCIÓN OQUITOA
# Sustituido en MUNICIPIO_RES
# 47
# con DESCRIPCIÓN PITIQUITO
# Sustituido en MUNICIPIO_RES
# 48
# con DESCRIPCIÓN PUERTO PEÑASCO
# Sustituido en MUNICIPIO_RES
# 49
# con DESCRIPCIÓN QUIRIEGO
# Sustituido en MUNICIPIO_RES
# 50
# con DESCRIPCIÓN RAYÓN
# Sustituido en MUNICIPIO_RES
# 51
# con DESCRIPCIÓN ROSARIO
# Sustituido en MUNICIPIO_RES
# 52
# con DESCRIPCIÓN SAHUARIPA
# Sustituido en MUNICIPIO_RES
# 53
# con DESCRIPCIÓN SAN FELIPE DE JESÚS
# Sustituido en MUNICIPIO_RES
# 54
# con DESCRIPCIÓN SAN JAVIER
# Sustituido en MUNICIPIO_RES
# 55
# con DESCRIPCIÓN SAN LUIS RÍO COLORADO
# Sustituido en MUNICIPIO_RES
# 56
# con DESCRIPCIÓN SAN MIGUEL DE HORCASITAS
# Sustituido en MUNICIPIO_RES
# 57
# con DESCRIPCIÓN SAN PEDRO DE LA CUEVA
# Sustituido en MUNICIPIO_RES
# 58
# con DESCRIPCIÓN SANTA ANA
# Sustituido en MUNICIPIO_RES
# 59
# con DESCRIPCIÓN SANTA CRUZ
# Sustituido en MUNICIPIO_RES
# 60
# con DESCRIPCIÓN SÁRIC
# Sustituido en MUNICIPIO_RES
# 61
# con DESCRIPCIÓN SOYOPA
# Sustituido en MUNICIPIO_RES
# 62
# con DESCRIPCIÓN SUAQUI GRANDE
# Sustituido en MUNICIPIO_RES
# 63
# con DESCRIPCIÓN TEPACHE
# Sustituido en MUNICIPIO_RES
# 64
# con DESCRIPCIÓN TRINCHERAS
# Sustituido en MUNICIPIO_RES
# 65
# con DESCRIPCIÓN TUBUTAMA
# Sustituido en MUNICIPIO_RES
# 66
# con DESCRIPCIÓN URES
# Sustituido en MUNICIPIO_RES
# 67
# con DESCRIPCIÓN VILLA HIDALGO
# Sustituido en MUNICIPIO_RES
# 68
# con DESCRIPCIÓN VILLA PESQUEIRA
# Sustituido en MUNICIPIO_RES
# 69
# con DESCRIPCIÓN YÉCORA
# Sustituido en MUNICIPIO_RES
# 70
# con DESCRIPCIÓN GENERAL PLUTARCO ELÍAS CALLES
# Sustituido en MUNICIPIO_RES
# 71
# con DESCRIPCIÓN BENITO JUÁREZ
# Sustituido en MUNICIPIO_RES
# 72
# con DESCRIPCIÓN SAN IGNACIO RÍO MUERTO
# Sustituido en MUNICIPIO_RES
# 999
# con DESCRIPCIÓN NO ESPECIFICADO
# Sustituido en MUNICIPIO_RES
# 1
# con DESCRIPCIÓN BALANCÁN
# Sustituido en MUNICIPIO_RES
# 2
# con DESCRIPCIÓN CÁRDENAS
# Sustituido en MUNICIPIO_RES
# 3
# con DESCRIPCIÓN CENTLA
# Sustituido en MUNICIPIO_RES
# 4
# con DESCRIPCIÓN CENTRO
# Sustituido en MUNICIPIO_RES
# 5
# con DESCRIPCIÓN COMALCALCO
# Sustituido en MUNICIPIO_RES
# 6
# con DESCRIPCIÓN CUNDUACÁN
# Sustituido en MUNICIPIO_RES
# 7
# con DESCRIPCIÓN EMILIANO ZAPATA
# Sustituido en MUNICIPIO_RES
# 8
# con DESCRIPCIÓN HUIMANGUILLO
# Sustituido en MUNICIPIO_RES
# 9
# con DESCRIPCIÓN JALAPA
# Sustituido en MUNICIPIO_RES
# 10
# con DESCRIPCIÓN JALPA DE MÉNDEZ
# Sustituido en MUNICIPIO_RES
# 11
# con DESCRIPCIÓN JONUTA
# Sustituido en MUNICIPIO_RES
# 12
# con DESCRIPCIÓN MACUSPANA
# Sustituido en MUNICIPIO_RES
# 13
# con DESCRIPCIÓN NACAJUCA
# Sustituido en MUNICIPIO_RES
# 14
# con DESCRIPCIÓN PARAÍSO
# Sustituido en MUNICIPIO_RES
# 15
# con DESCRIPCIÓN TACOTALPA
# Sustituido en MUNICIPIO_RES
# 16
# con DESCRIPCIÓN TEAPA
# Sustituido en MUNICIPIO_RES
# 17
# con DESCRIPCIÓN TENOSIQUE
# Sustituido en MUNICIPIO_RES
# 999
# con DESCRIPCIÓN NO ESPECIFICADO
# Sustituido en MUNICIPIO_RES
# 1
# con DESCRIPCIÓN ABASOLO
# Sustituido en MUNICIPIO_RES
# 2
# con DESCRIPCIÓN ALDAMA
# Sustituido en MUNICIPIO_RES
# 3
# con DESCRIPCIÓN ALTAMIRA
# Sustituido en MUNICIPIO_RES
# 4
# con DESCRIPCIÓN ANTIGUO MORELOS
# Sustituido en MUNICIPIO_RES
# 5
# con DESCRIPCIÓN BURGOS
# Sustituido en MUNICIPIO_RES
# 6
# con DESCRIPCIÓN BUSTAMANTE
# Sustituido en MUNICIPIO_RES
# 7
# con DESCRIPCIÓN CAMARGO
# Sustituido en MUNICIPIO_RES
# 8
# con DESCRIPCIÓN CASAS
# Sustituido en MUNICIPIO_RES
# 9
# con DESCRIPCIÓN CIUDAD MADERO
# Sustituido en MUNICIPIO_RES
# 10
# con DESCRIPCIÓN CRUILLAS
# Sustituido en MUNICIPIO_RES
# 11
# con DESCRIPCIÓN GÓMEZ FARÍAS
# Sustituido en MUNICIPIO_RES
# 12
# con DESCRIPCIÓN GONZÁLEZ
# Sustituido en MUNICIPIO_RES
# 13
# con DESCRIPCIÓN GÜÉMEZ
# Sustituido en MUNICIPIO_RES
# 14
# con DESCRIPCIÓN GUERRERO
# Sustituido en MUNICIPIO_RES
# 15
# con DESCRIPCIÓN GUSTAVO DÍAZ ORDAZ
# Sustituido en MUNICIPIO_RES
# 16
# con DESCRIPCIÓN HIDALGO
# Sustituido en MUNICIPIO_RES
# 17
# con DESCRIPCIÓN JAUMAVE
# Sustituido en MUNICIPIO_RES
# 18
# con DESCRIPCIÓN JIMÉNEZ
# Sustituido en MUNICIPIO_RES
# 19
# con DESCRIPCIÓN LLERA
# Sustituido en MUNICIPIO_RES
# 20
# con DESCRIPCIÓN MAINERO
# Sustituido en MUNICIPIO_RES
# 21
# con DESCRIPCIÓN EL MANTE
# Sustituido en MUNICIPIO_RES
# 22
# con DESCRIPCIÓN MATAMOROS
# Sustituido en MUNICIPIO_RES
# 23
# con DESCRIPCIÓN MÉNDEZ
# Sustituido en MUNICIPIO_RES
# 24
# con DESCRIPCIÓN MIER
# Sustituido en MUNICIPIO_RES
# 25
# con DESCRIPCIÓN MIGUEL ALEMÁN
# Sustituido en MUNICIPIO_RES
# 26
# con DESCRIPCIÓN MIQUIHUANA
# Sustituido en MUNICIPIO_RES
# 27
# con DESCRIPCIÓN NUEVO LAREDO
# Sustituido en MUNICIPIO_RES
# 28
# con DESCRIPCIÓN NUEVO MORELOS
# Sustituido en MUNICIPIO_RES
# 29
# con DESCRIPCIÓN OCAMPO
# Sustituido en MUNICIPIO_RES
# 30
# con DESCRIPCIÓN PADILLA
# Sustituido en MUNICIPIO_RES
# 31
# con DESCRIPCIÓN PALMILLAS
# Sustituido en MUNICIPIO_RES
# 32
# con DESCRIPCIÓN REYNOSA
# Sustituido en MUNICIPIO_RES
# 33
# con DESCRIPCIÓN RÍO BRAVO
# Sustituido en MUNICIPIO_RES
# 34
# con DESCRIPCIÓN SAN CARLOS
# Sustituido en MUNICIPIO_RES
# 35
# con DESCRIPCIÓN SAN FERNANDO
# Sustituido en MUNICIPIO_RES
# 36
# con DESCRIPCIÓN SAN NICOLÁS
# Sustituido en MUNICIPIO_RES
# 37
# con DESCRIPCIÓN SOTO LA MARINA
# Sustituido en MUNICIPIO_RES
# 38
# con DESCRIPCIÓN TAMPICO
# Sustituido en MUNICIPIO_RES
# 39
# con DESCRIPCIÓN TULA
# Sustituido en MUNICIPIO_RES
# 40
# con DESCRIPCIÓN VALLE HERMOSO
# Sustituido en MUNICIPIO_RES
# 41
# con DESCRIPCIÓN VICTORIA
# Sustituido en MUNICIPIO_RES
# 42
# con DESCRIPCIÓN VILLAGRÁN
# Sustituido en MUNICIPIO_RES
# 43
# con DESCRIPCIÓN XICOTÉNCATL
# Sustituido en MUNICIPIO_RES
# 999
# con DESCRIPCIÓN NO ESPECIFICADO
# Sustituido en MUNICIPIO_RES
# 1
# con DESCRIPCIÓN AMAXAC DE GUERRERO
# Sustituido en MUNICIPIO_RES
# 2
# con DESCRIPCIÓN APETATITLÁN DE ANTONIO CARVAJAL
# Sustituido en MUNICIPIO_RES
# 3
# con DESCRIPCIÓN ATLANGATEPEC
# Sustituido en MUNICIPIO_RES
# 4
# con DESCRIPCIÓN ATLTZAYANCA
# Sustituido en MUNICIPIO_RES
# 5
# con DESCRIPCIÓN APIZACO
# Sustituido en MUNICIPIO_RES
# 6
# con DESCRIPCIÓN CALPULALPAN
# Sustituido en MUNICIPIO_RES
# 7
# con DESCRIPCIÓN EL CARMEN TEQUEXQUITLA
# Sustituido en MUNICIPIO_RES
# 8
# con DESCRIPCIÓN CUAPIAXTLA
# Sustituido en MUNICIPIO_RES
# 9
# con DESCRIPCIÓN CUAXOMULCO
# Sustituido en MUNICIPIO_RES
# 10
# con DESCRIPCIÓN CHIAUTEMPAN
# Sustituido en MUNICIPIO_RES
# 11
# con DESCRIPCIÓN MUÑOZ DE DOMINGO ARENAS
# Sustituido en MUNICIPIO_RES
# 12
# con DESCRIPCIÓN ESPAÑITA
# Sustituido en MUNICIPIO_RES
# 13
# con DESCRIPCIÓN HUAMANTLA
# Sustituido en MUNICIPIO_RES
# 14
# con DESCRIPCIÓN HUEYOTLIPAN
# Sustituido en MUNICIPIO_RES
# 15
# con DESCRIPCIÓN IXTACUIXTLA DE MARIANO MATAMOROS
# Sustituido en MUNICIPIO_RES
# 16
# con DESCRIPCIÓN IXTENCO
# Sustituido en MUNICIPIO_RES
# 17
# con DESCRIPCIÓN MAZATECOCHCO DE JOSÉ MARÍA MORELOS
# Sustituido en MUNICIPIO_RES
# 18
# con DESCRIPCIÓN CONTLA DE JUAN CUAMATZI
# Sustituido en MUNICIPIO_RES
# 19
# con DESCRIPCIÓN TEPETITLA DE LARDIZÁBAL
# Sustituido en MUNICIPIO_RES
# 20
# con DESCRIPCIÓN SANCTÓRUM DE LÁZARO CÁRDENAS
# Sustituido en MUNICIPIO_RES
# 21
# con DESCRIPCIÓN NANACAMILPA DE MARIANO ARISTA
# Sustituido en MUNICIPIO_RES
# 22
# con DESCRIPCIÓN ACUAMANALA DE MIGUEL HIDALGO
# Sustituido en MUNICIPIO_RES
# 23
# con DESCRIPCIÓN NATÍVITAS
# Sustituido en MUNICIPIO_RES
# 24
# con DESCRIPCIÓN PANOTLA
# Sustituido en MUNICIPIO_RES
# 25
# con DESCRIPCIÓN SAN PABLO DEL MONTE
# Sustituido en MUNICIPIO_RES
# 26
# con DESCRIPCIÓN SANTA CRUZ TLAXCALA
# Sustituido en MUNICIPIO_RES
# 27
# con DESCRIPCIÓN TENANCINGO
# Sustituido en MUNICIPIO_RES
# 28
# con DESCRIPCIÓN TEOLOCHOLCO
# Sustituido en MUNICIPIO_RES
# 29
# con DESCRIPCIÓN TEPEYANCO
# Sustituido en MUNICIPIO_RES
# 30
# con DESCRIPCIÓN TERRENATE
# Sustituido en MUNICIPIO_RES
# 31
# con DESCRIPCIÓN TETLA DE LA SOLIDARIDAD
# Sustituido en MUNICIPIO_RES
# 32
# con DESCRIPCIÓN TETLATLAHUCA
# Sustituido en MUNICIPIO_RES
# 33
# con DESCRIPCIÓN TLAXCALA
# Sustituido en MUNICIPIO_RES
# 34
# con DESCRIPCIÓN TLAXCO
# Sustituido en MUNICIPIO_RES
# 35
# con DESCRIPCIÓN TOCATLÁN
# Sustituido en MUNICIPIO_RES
# 36
# con DESCRIPCIÓN TOTOLAC
# Sustituido en MUNICIPIO_RES
# 37
# con DESCRIPCIÓN ZILTLALTÉPEC DE TRINIDAD SÁNCHEZ SANTOS
# Sustituido en MUNICIPIO_RES
# 38
# con DESCRIPCIÓN TZOMPANTEPEC
# Sustituido en MUNICIPIO_RES
# 39
# con DESCRIPCIÓN XALOZTOC
# Sustituido en MUNICIPIO_RES
# 40
# con DESCRIPCIÓN XALTOCAN
# Sustituido en MUNICIPIO_RES
# 41
# con DESCRIPCIÓN PAPALOTLA DE XICOHTÉNCATL
# Sustituido en MUNICIPIO_RES
# 42
# con DESCRIPCIÓN XICOHTZINCO
# Sustituido en MUNICIPIO_RES
# 43
# con DESCRIPCIÓN YAUHQUEMEHCAN
# Sustituido en MUNICIPIO_RES
# 44
# con DESCRIPCIÓN ZACATELCO
# Sustituido en MUNICIPIO_RES
# 45
# con DESCRIPCIÓN BENITO JUÁREZ
# Sustituido en MUNICIPIO_RES
# 46
# con DESCRIPCIÓN EMILIANO ZAPATA
# Sustituido en MUNICIPIO_RES
# 47
# con DESCRIPCIÓN LÁZARO CÁRDENAS
# Sustituido en MUNICIPIO_RES
# 48
# con DESCRIPCIÓN LA MAGDALENA TLALTELULCO
# Sustituido en MUNICIPIO_RES
# 49
# con DESCRIPCIÓN SAN DAMIÁN TEXÓLOC
# Sustituido en MUNICIPIO_RES
# 50
# con DESCRIPCIÓN SAN FRANCISCO TETLANOHCAN
# Sustituido en MUNICIPIO_RES
# 51
# con DESCRIPCIÓN SAN JERÓNIMO ZACUALPAN
# Sustituido en MUNICIPIO_RES
# 52
# con DESCRIPCIÓN SAN JOSÉ TEACALCO
# Sustituido en MUNICIPIO_RES
# 53
# con DESCRIPCIÓN SAN JUAN HUACTZINCO
# Sustituido en MUNICIPIO_RES
# 54
# con DESCRIPCIÓN SAN LORENZO AXOCOMANITLA
# Sustituido en MUNICIPIO_RES
# 55
# con DESCRIPCIÓN SAN LUCAS TECOPILCO
# Sustituido en MUNICIPIO_RES
# 56
# con DESCRIPCIÓN SANTA ANA NOPALUCAN
# Sustituido en MUNICIPIO_RES
# 57
# con DESCRIPCIÓN SANTA APOLONIA TEACALCO
# Sustituido en MUNICIPIO_RES
# 58
# con DESCRIPCIÓN SANTA CATARINA AYOMETLA
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CLAVE'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-90a626e8bd1f> in <module>
#      48             try:
# ---> 49                 total_dbs[total_dbs_columns[c]]=total_dbs[total_dbs_columns[c]].replace(dbcat["CLAVE"][cl],dbcat["DESCRIPCIÓN"][cl])
#      50                 print("Sustituido en " + total_dbs_columns[c])
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CLAVE'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ENTIDAD_FEDERATIVA'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-90a626e8bd1f> in <module>
#      54                 try:
# ---> 55                     total_dbs[total_dbs_columns[c]]=total_dbs[total_dbs_columns[c]].replace(dbcat["CLAVE_ENTIDAD"][cl],dbcat["ENTIDAD_FEDERATIVA"][cl])
#      56                     print("Sustituido en " + total_dbs_columns[c])
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ENTIDAD_FEDERATIVA'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-90a626e8bd1f> in <module>
#      58                     print("con DESCRIPCIÓN " + dbcat["ENTIDAD_FEDERATIVA"][cl])
#      59                 except:
# ---> 60                     total_dbs[total_dbs_columns[c]]=total_dbs[total_dbs_columns[c]].replace(dbcat["CLAVE_MUNICIPIO"][cl],dbcat["MUNICIPIO"][cl])
#      61                     print("Sustituido en " + total_dbs_columns[c])
#      62                     print(dbcat["CLAVE_MUNICIPIO"][cl])
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3368         else:
#    3369             # set column
# -> 3370             self._set_item(key, value)
#    3371
#    3372     def _setitem_slice(self, key, value):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3444         self._ensure_valid_index(value)
#    3445         value = self._sanitize_column(key, value)
# -> 3446         NDFrame._set_item(self, key, value)
#    3447
#    3448         # check if we are modifying a copy
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in _set_item(self, key, value)
#    3170
#    3171     def _set_item(self, key, value):
# -> 3172         self._data.set(key, value)
#    3173         self._clear_item_cache()
#    3174
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\managers.py in set(self, item, value)
#    1072             blk_locs = blklocs[val_locs.indexer]
#    1073             if blk.should_store(value):
# -> 1074                 blk.set(blk_locs, value_getitem(val_locs))
#    1075             else:
#    1076                 unfit_mgr_locs.append(blk.mgr_locs.as_array[blk_locs])
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in set(self, locs, values)
#    2696         """
#    2697         try:
# -> 2698             self.values[locs] = values
#    2699         except (ValueError):
#    2700
#
# KeyboardInterrupt:

# %%
#total_dbs.tail()
total_dbs.columns

# %% [markdown]
# # INCONSISTENCIAS Y MANEJO DE ESTAS

# %% [markdown]
# ## Inconsistencia 1: Fecha menor a 2020
# Se elimina dato
#
# ## 2 fechas por ID
# Se mantiene fecha de última actualización, se asume corrección de error previo
# Se descartan defunciones anteriores a 2020
#
# ## Fecha de Actualización previa a Fecha de Defunción
# Se asume fecha de defunción igual a fecha de actualización

# %% [markdown]
# # ÚLTIMA ACTUALIZACIÓN DISPONIBLE

# %%
ultima_dbs=total_dbs.loc[total_dbs["FECHA_ACTUALIZACION"]==ultimo_reporte,:]
ultima_dbs.head()

# %% [markdown]
# # ANÁLISIS DEFUNCIONES

# %% [markdown]
# ## Total Defunciones (Nacional)

# %%
#Descartar pacientes vivos de la base total

defunciones_total_dbs=total_dbs.loc[(total_dbs["FECHA_DEF"] != "9999-99-99"),:]
defunciones_total_dbs.head()

# %% [markdown]
# #### INCONSISTENCIA 1: FECHAS MENORES A 2020
# Se eliminan casos

# %%
inconsistencia_1=defunciones_total_dbs.loc[(defunciones_total_dbs["FECHA_DEF"] < "2020-01-01"),:]
inconsistencia_1=inconsistencia_1.loc[:,["FECHA_ACTUALIZACION","ID_REGISTRO","FECHA_DEF"]]
inconsistencia_1_casos=inconsistencia_1.groupby(["ID_REGISTRO","FECHA_DEF"]).max()
inconsistencia_1_casos

# %%
#Definir si los casos fueron correjidos, agregar corrección a base

# %%
#Descartar casos de Inconsistencia 1

defunciones_total_dbs=defunciones_total_dbs.loc[(defunciones_total_dbs["FECHA_DEF"] >= "2020-01-01"),:]
defunciones_total_dbs["FECHA_DEF"].unique()

# %% [markdown]
# ### INCONSISTENCIA 2: FECHAS DE DEFUNCIÓN DIFERENTES PARA MISMO PACIENTE
# Se asume que la fecha registrada en la última base de datos es la más certera

# %%
inconsistencia_2=defunciones_total_dbs.loc[:,["ID_REGISTRO","FECHA_DEF","FECHA_ACTUALIZACION"]]
inconsistencia_2=inconsistencia_2.groupby(["ID_REGISTRO","FECHA_DEF"],as_index=False).count()
inconsistencia_2=inconsistencia_2.groupby(["ID_REGISTRO"],as_index=False).count()
inconsistencia_2=inconsistencia_2.loc[(inconsistencia_2["FECHA_DEF"]>1),["ID_REGISTRO","FECHA_DEF"]]
inconsistencia_2.count()

# %%
#Se asume que la fecha registrada en la última base de datos como la más cierta
fecha_defuncion=ultima_dbs.loc[(ultima_dbs["FECHA_DEF"] != "9999-99-99") & (ultima_dbs["FECHA_DEF"] >="2020-01-01"),["FECHA_DEF","ENTIDAD_UM","ID_REGISTRO","RESULTADO"]]

#Obtener fecha de registro de muerte de cada paciente (primer base de datos que se reportó la muerte)
fecha_registro=defunciones_total_dbs.loc[:,["ID_REGISTRO","FECHA_ACTUALIZACION"]]
fecha_registro=fecha_registro.groupby(["ID_REGISTRO"],as_index=False).min()

#Base para análisis de defunciones diarias, atrasos de notificación (relacionado a tiempo desde la defunción)
defunciones_consolidado_tiempo=fecha_registro.merge(fecha_defuncion,on="ID_REGISTRO")
defunciones_consolidado_tiempo.head()

# %% [markdown]
# ### Atraso de Resultado Vs Fecha Defunción

# %%
#Formato de fechas
defunciones_consolidado_tiempo["FECHA_DEF"]=pd.to_datetime(defunciones_consolidado_tiempo["FECHA_DEF"].str.strip(), format="%Y-%m-%d")
defunciones_consolidado_tiempo["FECHA_ACTUALIZACION"]=pd.to_datetime(defunciones_consolidado_tiempo["FECHA_ACTUALIZACION"], format="%Y-%m-%d")
defunciones_consolidado_tiempo.head()

# %%
defunciones_consolidado_tiempo["ATRASO_NOTIFICACION"]=(defunciones_consolidado_tiempo["FECHA_ACTUALIZACION"]-defunciones_consolidado_tiempo["FECHA_DEF"]).dt.days
defunciones_consolidado_tiempo.head()

# %% [markdown]
# ### Muertes confirmadas por rango de días
#
# Confirmados dentro de los primeros 3 días (expectativa normal)
#
# Confirmados hasta 7 días después (atraso dentro de lo esperado)
#
# Confirmados hasta 2 semanas después (atraso doble a lo esperado)
#
# Confirmados después de 2 semanas (atraso excesivo)

# %%
bins=[-1,3,7,14,max(defunciones_consolidado_tiempo["ATRASO_NOTIFICACION"])]
atraso_etiquetas=("72hrs", "1 semana","2 semanas", "+2 semanas")

defunciones_consolidado_tiempo["RANGO_ATRASO"]=pd.cut(defunciones_consolidado_tiempo["ATRASO_NOTIFICACION"],bins,labels=atraso_etiquetas)
defunciones_consolidado_tiempo.head()

# %% [markdown]
# ### Estadísticas directas

# %% [markdown]
# #### Casos por Resultado
# De los casos registrados, cuántos y en qué porcentaje han resultado como Positivo SARS-CoV-2, No Positivo SARS-CoV-2 y cuántos se mantienen pendientes de resultado

# %%
defunciones_resultado=defunciones_consolidado_tiempo.loc[:,["RESULTADO","ID_REGISTRO"]]
defunciones_resultado=defunciones_resultado.groupby(["RESULTADO"], as_index=False).count()
defunciones_resultado=defunciones_resultado.rename(columns={"ID_REGISTRO":"NUM_CASOS"})
defunciones_resultado=defunciones_resultado.sort_values(by=["NUM_CASOS"])
defunciones_resultado

# %%
fig,ax = plt.subplots()

fig.set_size_inches(10.5, 10.5)

labels=defunciones_resultado["RESULTADO"]
sizes=defunciones_resultado["NUM_CASOS"]
colors=["gold","blue","red"]

pie= plt.pie(sizes,colors=colors,
        autopct="%1.1f%%",textprops={'fontsize': 18},pctdistance=1.2,
       labels=None, startangle=-270)
plt.legend(pie[0],labels, bbox_to_anchor=(1,0.5), loc=3, fontsize=14, 
           bbox_transform=plt.gcf().transFigure)

plt.title("DISTRIBUCIÓN DE DEFUNCIONES POR RESULTADO", fontsize=20, weight="bold")

# %% [markdown]
# #### Muertes confirmadas por día

# %%
defunciones_covid_diarias=defunciones_consolidado_tiempo.loc[defunciones_consolidado_tiempo["RESULTADO"]=="Positivo SARS-CoV-2",:]
defunciones_covid_diarias=defunciones_covid_diarias.loc[:,["FECHA_DEF","ID_REGISTRO"]]

defunciones_covid_diarias=defunciones_covid_diarias.groupby(["FECHA_DEF"],as_index=False).count()
defunciones_covid_diarias=defunciones_covid_diarias.rename(columns={"ID_REGISTRO":"NUM_CASOS_COVID"})                                                          
defunciones_covid_diarias.head()

# %%
max_covid_dia=defunciones_covid_diarias.loc[defunciones_covid_diarias["NUM_CASOS_COVID"]==max(defunciones_covid_diarias["NUM_CASOS_COVID"]),:]
max_covid_dia

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])

fig.set_size_inches(18.5, 10.5)
y_axis=defunciones_covid_diarias["FECHA_DEF"]
x_axis=defunciones_covid_diarias["NUM_CASOS_COVID"]
ax.bar(y_axis,x_axis,color="red")
ax.xaxis.set_major_formatter(mdates.DateFormatter("%B"))
ax.xaxis.set_major_locator(mdates.MonthLocator())

ax.set_xlabel("Días",fontsize=20)
ax.set_ylabel("Casos", fontsize=20)

ax.tick_params(labelsize=15)


ax.set_title("DEFUNCIONES CON RESULTADO POSITIVO A SARS-COV-2", fontsize=24, weight="bold")

# %%
defunciones_sospechosas_diarias=defunciones_consolidado_tiempo.loc[defunciones_consolidado_tiempo["RESULTADO"]=="Resultado pendiente",:]
defunciones_sospechosas_diarias=defunciones_sospechosas_diarias.loc[:,["FECHA_DEF","ID_REGISTRO"]]

defunciones_sospechosas_diarias=defunciones_sospechosas_diarias.groupby(["FECHA_DEF"],as_index=False).count()
defunciones_sospechosas_diarias=defunciones_sospechosas_diarias.rename(columns={"ID_REGISTRO":"NUM_CASOS_SOSPECHOSOS"})
defunciones_sospechosas_diarias.head()

# %%
max_sospechosas_dia=defunciones_sospechosas_diarias.loc[defunciones_sospechosas_diarias["NUM_CASOS_SOSPECHOSOS"]==max(defunciones_sospechosas_diarias["NUM_CASOS_SOSPECHOSOS"]),:]

max_sospechosas_dia

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])

fig.set_size_inches(18.5, 10.5)
y_axis=defunciones_sospechosas_diarias["FECHA_DEF"]
x_axis=defunciones_sospechosas_diarias["NUM_CASOS_SOSPECHOSOS"]
ax.bar(y_axis,x_axis,color="yellow")
ax.xaxis.set_major_formatter(mdates.DateFormatter("%B"))
ax.xaxis.set_major_locator(mdates.MonthLocator())

ax.set_xlabel("Días",fontsize=20)
ax.set_ylabel("Casos", fontsize=20)

ax.tick_params(labelsize=15)

ax.set_title("DEFUNCIONES PENDIENTES DE RESULTADO", fontsize=24, weight="bold")

# %%
confirmadas_sospechosas_diarias=defunciones_covid_diarias.merge(defunciones_sospechosas_diarias,on="FECHA_DEF", how="outer")
confirmadas_sospechosas_diarias.head()

# %%
fig,ax = plt.subplots()

fig.set_size_inches(18.5, 10.5)
x_axis=confirmadas_sospechosas_diarias["NUM_CASOS_COVID"]
x_axis2=confirmadas_sospechosas_diarias["NUM_CASOS_SOSPECHOSOS"]
y_axis=confirmadas_sospechosas_diarias["FECHA_DEF"]

ax.bar(y_axis,x_axis, color="red")
ax.bar(y_axis,x_axis2, bottom=x_axis, color="yellow")


ax.xaxis.set_major_formatter(mdates.DateFormatter("%B"))
ax.xaxis.set_major_locator(mdates.MonthLocator())

ax.set_xlabel("Días",fontsize=20)
ax.set_ylabel("Casos", fontsize=20)

ax.tick_params(labelsize=15)

ax.set_title("DEFUNCIONES CONFIRMADAS POR SARS-COV-2 Y PENDIENTES DE RESULTADO", fontsize=20, weight="bold")

# %%
defunciones_consolidado_tiempo.head()

# %%
defunciones_covid_atraso=defunciones_consolidado_tiempo.loc[defunciones_consolidado_tiempo["RESULTADO"]=="Positivo SARS-CoV-2",:]
defunciones_covid_atraso.head()

# %% [markdown]
# ### INCONSISTENCIA 3: FECHA NOTIFICACIÓN PREVIA A FECHA DEFUNCIÓN
#
# Se eliminan los casos cuya fecha de notificación de defunción es menor a la fecha de defunción registrada

# %%
inconsistencia_3=defunciones_covid_atraso.loc[defunciones_covid_atraso["ATRASO_NOTIFICACION"]<0,:]
inconsistencia_3

# %%
defunciones_covid_atraso=defunciones_covid_atraso.loc[defunciones_covid_atraso["ATRASO_NOTIFICACION"]>=0,:]
defunciones_covid_atraso.head()

# %% [markdown]
# ### DEFUNCIONES CONFIRMADAS POR COVID Y ATRASO EN CONFIRMACIÓN

# %%
resumen_defunciones_covid_atraso=defunciones_covid_atraso.loc[:,["ATRASO_NOTIFICACION"]]
resumen_defunciones_covid_atraso.describe()

# %%
resumen_defunciones_covid_atraso_ajustado=defunciones_covid_atraso.loc[defunciones_covid_atraso["FECHA_DEF"]>=primer_reporte,:]
resumen_defunciones_covid_atraso_ajustado=resumen_defunciones_covid_atraso_ajustado.loc[:,["ATRASO_NOTIFICACION"]]
resumen_defunciones_covid_atraso_ajustado.describe()

# %%
defunciones_covid_rango=defunciones_covid_atraso.loc[:,["RANGO_ATRASO","ID_REGISTRO"]]
defunciones_covid_rango=defunciones_covid_rango.groupby(["RANGO_ATRASO"],as_index=False).count()
defunciones_covid_rango=defunciones_covid_rango.rename(columns={"ID_REGISTRO":"NUM_CASOS_COVID"})
defunciones_covid_rango

# %%
defunciones_covid_rango_ajustado=defunciones_covid_atraso.loc[:,["FECHA_DEF","RANGO_ATRASO","ID_REGISTRO"]]
defunciones_covid_rango_ajustado=defunciones_covid_rango_ajustado.loc[defunciones_covid_rango_ajustado["FECHA_DEF"]>=primer_reporte,:]
defunciones_covid_rango_ajustado=defunciones_covid_rango_ajustado.loc[:,["RANGO_ATRASO","ID_REGISTRO"]]

defunciones_covid_rango_ajustado=defunciones_covid_rango_ajustado.groupby(["RANGO_ATRASO"],as_index=False).count()
defunciones_covid_rango_ajustado=defunciones_covid_rango_ajustado.rename(columns={"ID_REGISTRO":"NUM_CASOS_COVID*"})
defunciones_covid_rango_ajustado

# %%
fig,ax = plt.subplots()

fig.set_size_inches(10.5, 10.5)

labels=defunciones_covid_rango_ajustado["RANGO_ATRASO"]
sizes=defunciones_covid_rango_ajustado["NUM_CASOS_COVID*"]
colors=["green","yellow","orange","red"]

pie=plt.pie(sizes,colors=colors,
            autopct="%1.1f%%",textprops={'fontsize': 18},pctdistance=1.1,
            labels=None, startangle=0)

plt.legend(pie[0],labels, bbox_to_anchor=(1,0.5), loc=3, fontsize=14, 
           bbox_transform=plt.gcf().transFigure)

plt.title("TIEMPO TRANSCURRIDO ENTRE DEFUNCIÓN Y FECHA DE REGISTRO COMO CASO POSITIVO SARS-CoV-2", fontsize=20, weight="bold")

# %%
defunciones_covid_atraso.head()

# %%
defunciones_covid_atraso_3dias=defunciones_covid_atraso.loc[defunciones_covid_atraso["RANGO_ATRASO"]=="72hrs",:]
defunciones_covid_atraso_3dias=defunciones_covid_atraso_3dias.loc[:,["ID_REGISTRO","FECHA_DEF"]]
defunciones_covid_atraso_3dias=defunciones_covid_atraso_3dias.groupby(["FECHA_DEF"],as_index=False).count()

# %%
defunciones_covid_atraso_1sem=defunciones_covid_atraso.loc[defunciones_covid_atraso["RANGO_ATRASO"]=="1 semana",:]
defunciones_covid_atraso_1sem=defunciones_covid_atraso_1sem.loc[:,["ID_REGISTRO","FECHA_DEF"]]
defunciones_covid_atraso_1sem=defunciones_covid_atraso_1sem.groupby(["FECHA_DEF"],as_index=False).count()

# %%
defunciones_covid_atraso_2sem=defunciones_covid_atraso.loc[defunciones_covid_atraso["RANGO_ATRASO"]=="2 semanas",:]
defunciones_covid_atraso_2sem=defunciones_covid_atraso_2sem.loc[:,["ID_REGISTRO","FECHA_DEF"]]
defunciones_covid_atraso_2sem=defunciones_covid_atraso_2sem.groupby(["FECHA_DEF"],as_index=False).count()

# %%
defunciones_covid_atraso_2semplus=defunciones_covid_atraso.loc[defunciones_covid_atraso["RANGO_ATRASO"]=="+2 semanas",:]
defunciones_covid_atraso_2semplus=defunciones_covid_atraso_2semplus.loc[:,["ID_REGISTRO","FECHA_DEF"]]
defunciones_covid_atraso_2semplus=defunciones_covid_atraso_2semplus.groupby(["FECHA_DEF"],as_index=False).count()

# %%
defunciones_diarias_covid_atraso=defunciones_covid_atraso_3dias.merge(defunciones_covid_atraso_1sem,on="FECHA_DEF",how="outer")
defunciones_diarias_covid_atraso=defunciones_diarias_covid_atraso.rename(columns={"ID_REGISTRO_x":"3_DIAS","ID_REGISTRO_y":"1_SEMANA"})

defunciones_diarias_covid_atraso=defunciones_diarias_covid_atraso.merge(defunciones_covid_atraso_2sem,on="FECHA_DEF",how="outer")
defunciones_diarias_covid_atraso=defunciones_diarias_covid_atraso.rename(columns={"ID_REGISTRO":"2_SEMANAS"})

defunciones_diarias_covid_atraso=defunciones_diarias_covid_atraso.merge(defunciones_covid_atraso_2semplus,on="FECHA_DEF",how="outer")
defunciones_diarias_covid_atraso=defunciones_diarias_covid_atraso.rename(columns={"ID_REGISTRO":"+2_SEMANAS"})

defunciones_diarias_covid_atraso=defunciones_diarias_covid_atraso.sort_values(by=["FECHA_DEF"])

defunciones_diarias_covid_atraso=defunciones_diarias_covid_atraso.fillna(0)

defunciones_diarias_covid_atraso.tail(20)

# %%
defunciones_diarias_covid_atraso.dtypes

# %%
fig,ax = plt.subplots()

fig.set_size_inches(18.5, 10.5)
x_axis=defunciones_diarias_covid_atraso["3_DIAS"]
x_axis2=defunciones_diarias_covid_atraso["1_SEMANA"]
x_axis3=defunciones_diarias_covid_atraso["2_SEMANAS"]
x_axis4=defunciones_diarias_covid_atraso["+2_SEMANAS"]
y_axis=defunciones_diarias_covid_atraso["FECHA_DEF"]

bars=np.add(defunciones_diarias_covid_atraso["3_DIAS"],defunciones_diarias_covid_atraso["1_SEMANA"]).tolist()
bars2=np.add(bars,defunciones_diarias_covid_atraso["2_SEMANAS"]).tolist()
bars3=np.add(bars2,defunciones_diarias_covid_atraso["+2_SEMANAS"]).tolist()

axes = plt.gca()
axes.set_ylim([0,int(max_covid_dia["NUM_CASOS_COVID"])*1.1])

ax.bar(y_axis,x_axis, color="green",label="3 días")
ax.bar(y_axis,x_axis2, bottom=x_axis, color="yellow", label="1 semana")
ax.bar(y_axis,x_axis3, bottom=bars, color="orange",label="2 semanas")
ax.bar(y_axis,x_axis4, bottom=bars2, color="red",label="+2 semanas")

plt.axvline(x=primer_reporte,color="blue",label="Primer reporte")

plt.legend(fontsize=15)

ax.set_xlabel("Días",fontsize=20)
ax.set_ylabel("Casos", fontsize=20)

ax.tick_params(labelsize=15)

ax.xaxis.set_major_formatter(mdates.DateFormatter("%B"))
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.set_title("ATRASO EN CONFIRMACIÓN DE DEFUNCIONES POSITIVAS A SARS-COV-2", fontsize=20, weight="bold")

# %% [markdown]
# ### DEFUNCIONES COVID CONFIRMADAS: HISTORIAL DE REPORTES

# %%
total_dbs.columns

# %%
#Obtener fecha en la cual el ID_REGISTRO fue incluida en las bases de datos 
#(primera base de datos en la cual aparece el ID)

primer_registro_ID=total_dbs.loc[:,["FECHA_ACTUALIZACION","ID_REGISTRO"]]
primer_registro_ID=primer_registro_ID.groupby(["ID_REGISTRO"],as_index=False).min()
primer_registro_ID=primer_registro_ID.rename(columns={"FECHA_ACTUALIZACION":"FECHA_ID_PRIMER_REPORTE"})
primer_registro_ID.head()

# %%
#AUXILIAR: Obtener de la base completa la información para cruzar con el reporte del primer registro de cada ID

primer_registro_status_auxiliar=total_dbs.loc[:,["ID_REGISTRO","FECHA_ACTUALIZACION","FECHA_DEF","RESULTADO"]]
primer_registro_status_auxiliar=primer_registro_status_auxiliar.rename(columns={"RESULTADO":"RESULTADO_INICIAL", 
                                                                                "FECHA_ACTUALIZACION":"FECHA_ID_PRIMER_REPORTE"})
primer_registro_status_auxiliar.head()

# %%
#Obtener estado de paciente (Vivo - Fallecido) y Resultado de Prueba en el primer reporte de cada ID_REGISTRO
#Vivo: FECHA_DEF = "9999-99-99"
#Fallecido: FECHA_DEF != "9999-99-99"

primer_registro_ID_status=primer_registro_ID.merge(primer_registro_status_auxiliar,
                                                   left_on=["ID_REGISTRO","FECHA_ID_PRIMER_REPORTE"],
                                                   right_on=["ID_REGISTRO","FECHA_ID_PRIMER_REPORTE"],
                                                  how="left")
primer_registro_ID_status=primer_registro_ID_status.rename(columns={"FECHA_DEF":"STATUS_INICIAL"})
primer_registro_ID_status=primer_registro_ID_status.loc[:,["ID_REGISTRO","FECHA_ID_PRIMER_REPORTE","STATUS_INICIAL","RESULTADO_INICIAL"]]
primer_registro_ID_status.head()

# %%
#primer_registro_UCI_auxiliar, obtiene información de ID_REGISTRO, FECHA_ACTUALIZACION, UCI, RESULTADO para identificar
#el primer registro de uso de UCI

#primer_registro_UCI, base con información de fecha de primer registro con UCI, y RESULTADO en esa fecha

primer_registro_UCI_auxiliar=total_dbs.loc[:,["ID_REGISTRO","FECHA_ACTUALIZACION","UCI","RESULTADO"]]
primer_registro_UCI_auxiliar=primer_registro_UCI_auxiliar.loc[primer_registro_UCI_auxiliar["UCI"].str.contains("SI"),:]

primer_registro_UCI=primer_registro_UCI_auxiliar.loc[:,["ID_REGISTRO","FECHA_ACTUALIZACION","UCI"]]
primer_registro_UCI=primer_registro_UCI.groupby(["ID_REGISTRO","UCI"], as_index=False).min()
primer_registro_UCI=primer_registro_UCI.merge(primer_registro_UCI_auxiliar,on=["ID_REGISTRO","FECHA_ACTUALIZACION","UCI"])
primer_registro_UCI=primer_registro_UCI.rename(columns={"FECHA_ACTUALIZACION":"FECHA_UCI"})
primer_registro_UCI.head()

# %%
defunciones_consolidado=defunciones_consolidado_tiempo.merge(primer_registro_ID_status,on=["ID_REGISTRO"])
defunciones_consolidado=defunciones_consolidado.rename(columns={"FECHA_ACTUALIZACION":"FECHA_PRIMER_REPORTE_DEFUNCION",
                                                                             "RESULTADO":"RESULTADO_ULTIMO"})
defunciones_consolidado["STATUS_INICIAL"]=defunciones_consolidado["STATUS_INICIAL"].replace("9999-99-99","Vivo")
defunciones_consolidado["STATUS_INICIAL"][defunciones_consolidado["STATUS_INICIAL"]!="Vivo"]="Fallecido"
defunciones_consolidado=defunciones_consolidado.merge(primer_registro_UCI,how="left",on="ID_REGISTRO")
defunciones_consolidado.head()

# %%
defunciones_status_inicial=defunciones_consolidado.loc[:,["STATUS_INICIAL","ID_REGISTRO"]]
defunciones_status_inicial=defunciones_status_inicial.groupby(["STATUS_INICIAL"],as_index=False).count()
defunciones_status_inicial=defunciones_status_inicial.rename(columns={"ID_REGISTRO":"NUM_CASOS"})
defunciones_status_inicial

# %%
fig,ax = plt.subplots()

fig.set_size_inches(10.5, 10.5)

labels=defunciones_status_inicial["STATUS_INICIAL"]
sizes=defunciones_status_inicial["NUM_CASOS"]
colors=["red","green"]

pie=plt.pie(sizes,colors=colors,
            autopct="%1.1f%%",textprops={'fontsize': 18},pctdistance=1.1,
            labels=None, startangle=0)

plt.legend(pie[0],labels, bbox_to_anchor=(1,0.5), loc=3, fontsize=14, 
           bbox_transform=plt.gcf().transFigure)

plt.title("ESTADO DE LA PERSONA CUANDO FUE REGISTRADA EN LA BASE DE DATOS", fontsize=20, weight="bold")

# %%
defunciones_consolidado_resultados_evolucion=defunciones_consolidado.loc[:,["ID_REGISTRO","RESULTADO_INICIAL","RESULTADO_ULTIMO"]]
defunciones_consolidado_resultados_evolucion=defunciones_consolidado_resultados_evolucion.groupby(["RESULTADO_ULTIMO","RESULTADO_INICIAL"],as_index=False).count()
defunciones_consolidado_resultados_evolucion

# %%
defunciones_consolidado_resultados_estado_inicial=defunciones_consolidado_status.loc[:,["ID_REGISTRO","STATUS_INICIAL","RESULTADO_INICIAL","RESULTADO_ULTIMO"]]
defunciones_consolidado_resultados_estado_inicial=defunciones_consolidado_resultados_estado_inicial.groupby(["RESULTADO_ULTIMO","STATUS_INICIAL","RESULTADO_INICIAL"],as_index=False).count()
defunciones_consolidado_resultados_estado_inicial=defunciones_consolidado_resultados_estado_inicial[["STATUS_INICIAL","RESULTADO_INICIAL","RESULTADO_ULTIMO","ID_REGISTRO"]]
defunciones_consolidado_resultados_estado_inicial

# %%
defunciones_positivas_estado_inicial=defunciones_consolidado_resultados_estado_inicial.loc[defunciones_consolidado_resultados_estado_inicial["RESULTADO_ULTIMO"]=="Positivo SARS-CoV-2",:]
defunciones_positivas_estado_inicial

# %%
#Fecha Actualización (mínima) Vs Fecha Defunción
    #Determinar % promedio de muertes totales notificadas en día 1, cuándo cada cuartil
    #Gráfica cajas

#Fecha Síntomas Vs Fecha Actualización (mínima) - Cuánto tarda la persona en acudir al médico en promedio

#% de letalidad con cada comorbilidad

#% de letalidad con intubación

#Respuesta de sospechosos promedio

#Casos que no fueron sospechosos
